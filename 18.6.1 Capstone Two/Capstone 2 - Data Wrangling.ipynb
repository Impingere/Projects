# %% [markdown]
# # Emotion Recognition in Speech - Data Wrangling

# %% [markdown]
# ## Contents

# %% [markdown]
# * [Introduction](#Introduction)
#     * [Data Science Problem](#Data_Science_Problem)
# * [Imports](#Imports)
# * [Objectives](#Objectives)
# * [About the RAVDESS dataset](#About_the_RAVDESS_dataset)
# * [About the CREMA-D dataset](#About_the_CREMA-D_dataset)
#     * [Loading and Visualizing an Audio File (RAVDESS)](#Loading_and_Visualizing_an_Audio_File_(RAVDESS))
#     * [Audio File information](#Audio_File_information)
#     * [Playing a sample](#Playing_a_sample)
# * [Vizualizing](#Vizualizing)
#     * [Visualizing the Audio File](#Visualizing_the_Audio_File)
#     * [Trimming the file](#Trimming_the_file)
#     * [Spectrogram](#Spectrogram)
#     * [Display in log-frequency](#Display_in_log-frequency)
#     * [Down Sampling Test](#Down_Sampling_Test)
#     * [MFCC, Chroma, Mel Test](#MFCC,_Chroma,_Mel_Test)
# * [Creating a dataframe](#Creating_a_dataframe)
#     * [RAVDESS dataframe](#RAVDESS_dataframe)
#     * [CREMA-D dataframe](#CREMA-D_dataframe)
#     * [TESS dataframe](#TESS_dataframe)
# * [Exploring the dataframe](#Exploring_the_dataframe)
#     * [Strong vs normal emotion](#Strong_vs_normal_emotion)
#     * [Number of repeated phrases](#Number_of_repeated_phrases)
#     * [Number of Male vs Female actors](#Number_of_Male_vs_Female_actors)
#     * [Emotions](#Emotions)
#     * [Statements](#Statements)
# * [Cleaning the dataframe](#Cleaning_the_dataframe)
#     * [Checking for duplicate values RAVDESS](#Checking_for_duplicate_values_RAVDESS)
#     * [Cleaning up outliers](#Cleaning_up_outliers)
#     * [Checking for missing values in RAVDESS](#Checking_for_missing_values_in_RAVDESS)
#     * [Checking for missing values in CREMA-D](#Checking_for_missing_values_in_CREMA-D)
#     * [Distributions Of Feature Values](#Distributions_Of_Feature_Values)
#     * [Numeric data summary](#Numeric_data_summary)
# * [Exporting DataFrame](#Exporting_DataFrame)
# * [Summary](#Summary)

# %% [markdown]
# ## Introduction

# %% [markdown]
# This step focuses on collecting data, organizing it, and making sure it's well defined.
# Attention to these tasks will pay off greatly later on. Some data cleaning can be done at this stage,
# but it's important not to be overzealous in your cleaning before we've explored the data to better understand it.

# %% [markdown]
# ### Data Science Problem<a id='Data_Science_Problem'></a>

# %% [markdown]
# The purpose of this data science project is to come up with a predictive model for emotion recognition in speech.
# We suspects it may have better responses to human / robot interaction based on categories of emotion detect
# from customers with audio-enabled bots. The categorization of the customer's emotial state can better atune a variety
# of optional responses to customize interations. This project aims to build a predictive model for emotion recognition
# based on a set of actor data that falls into 8 categories of emotional state. This model will be used to provide
# guidance for an audio-enabled bot's available responses and future customer interaction.

# %% [markdown]
# ## Imports

# %%
# Importing librosa, soundfile, pandas, os, glob, pickle, numpy, matplotlib, seaborn and warnings in the lines below
import librosa
import librosa.display
import soundfile
import pandas as pd
import os, glob, pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import IPython.display as ipd

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

from dotenv import load_dotenv, find_dotenv

import warnings

# Suppress specific FutureWarnings related to seaborn and pandas
warnings.filterwarnings('ignore', category=FutureWarning, module='seaborn')
warnings.filterwarnings('ignore', category=FutureWarning, module='pandas')

load_dotenv()
sound_path = os.getenv('audio_path')

# %% [markdown]
# ## Objectives

# %% [markdown]
# There are some fundamental questions to resolve in this notebook.
#
# •Do we may have the data we need to tackle the desired question?
#       •Have we identified the required target value?
#       •Do we have potentially useful features?
# •Do we have any fundamental issues with the data?

# %% [markdown]
# ## About the RAVDESS dataset<a id='About_the_RAVDESS_dataset'></a>

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# This dataset is pulled from the Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS). It has
# classifications that are contained in the file names. They are as follows:
#
# Filename identifiers
#
# Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# Vocal channel (01 = speech, 02 = song).
#
# Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# Audio-only (03)
# Speech (01)
# Fearful (06)
# Normal intensity (01)
# Statement "dogs" (02)
# 1st Repetition (01)
# 12th Actor (12)
# Female, as the actor ID number is even.
#
# Academic citation
#
# If you use the RAVDESS in an academic publication, please use the following citation: Livingstone SR, Russo FA (2018)
#     The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS): A dynamic, multimodal set of facial and
#         vocal expressions in North American English. PLoS ONE 13(5): e0196391. https://doi.org/10.1371/journal.pone.0196391.
#
# All other attributions
#
# If you use the RAVDESS in a form other than an academic publication, such as in a blog post, school project, or
# non-commercial product, please use the following attribution: "The Ryerson Audio-Visual Database of Emotional Speech
#     and Song (RAVDESS)" by Livingstone & Russo is licensed under CC BY-NA-SC 4.0.

# %% [markdown]
# ## About the CREMA-D dataset<a id='About_the_CREMA-D_dataset'></a>

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# Filename labeling conventions
# The Actor id is a 4 digit number at the start of the file. Each subsequent identifier is separated by an underscore (_).
#
#
# Actors spoke from a selection of 12 sentences
# (in parentheses is the three letter acronym used in the second part of the filename):
#
#
#     It's eleven o'clock (IEO).
#     That is exactly what happened (TIE).
#     I'm on my way to the meeting (IOM).
#     I wonder what this is about (IWW).
#     The airplane is almost full (TAI).
#     Maybe tomorrow it will be cold (MTI).
#     I would like a new alarm clock (IWL).
#     I think I have a doctor's appointment (ITH).
#     Don't forget a jacket (DFA).
#     I think I've seen this before (ITS).
#     The surface is slick (TSI).
#     We'll stop in a couple of minutes (WSI).
#
#
# The sentences were presented using different emotion
# (in parentheses is the three letter code used in the third part of the filename):
#
#
#     Anger (ANG)
#     Disgust (DIS)
#     Fear (FEA)
#     Happy/Joy (HAP)
#     Neutral (NEU)
#     Sad (SAD)
#
#
# and emotion level (in parentheses is the two letter code used in the fourth part of the filename):
#
# Low (LO)
# Medium (MD)
# High (HI)
# Unspecified (XX)
# The suffix of the filename is based on the type of file, flv for flash video used for presentation of
# both the video only, and the audio-visual clips. mp3 is used for the audio files used for the audio-only
# presentation of the clips. wav is used for files used for computational audio processing.
#
# This dataset did not have sex classification in the file name so I had to post process the csv file with information from the actor sheet on the original github site: https://github.com/CheyneyComputerScience/CREMA-D

# %% [markdown]
# ### Loading and Visualizing an Audio File (RAVDESS)<a id='Loading_and_Visualizing_an_Audio_File_(RAVDESS)'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# path of the audio file
audio_data = f'{sound_path}/ravdess-data/Actor_01/03-01-01-01-01-01-01.wav'
# This returns an audio time series as a numpy array with a default sampling rate(sr) of 22KHZ
x, sr = librosa.load(audio_data, sr=44000)

# We can change this behavior by resampling at sr=44.1KHz.
# x = librosa.load(audio_data, sr=44000)

# %% [markdown]
# ### Audio File information<a id='Audio_File_information'></a>

# %%
print(x.shape)
print(sr)
# Out:
# (145346,)
# 44000

# %% [markdown]
# ### Playing a sample<a id='Playing_a_sample'></a>

# %%
ipd.Audio(f'{sound_path}/ravdess-data/Actor_01/03-01-01-01-01-01-01.wav') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### CREMA-D dataset

# %%
# path of the audio file
audio_data = f'{sound_path}/CREMA-D/1001_DFA_ANG_XX.wav'
# This returns an audio time series as a numpy array with a default sampling rate(sr) of 22KHZ
x, sr = librosa.load(audio_data, sr=44000)

# We can change this behavior by resampling at sr=44.1KHz.
# x = librosa.load(audio_data, sr=44000)

# %%
print(x.shape)
print(sr)
# Out:
# (100125,)
# 44000

# %%
ipd.Audio(f'{sound_path}/CREMA-D/1001_DFA_ANG_XX.wav') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Vizualizing

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# ### Visualizing the Audio File<a id='Visualizing_the_Audio_File'></a>

# %%
# %matplotlib inline

plt.figure(figsize=(14, 5))
# plotting the sampled signal
librosa.display.waveshow(x, sr=sr)

# %% [markdown]
# ### Trimming the file<a id='Trimming_the_file'></a>

# %%
# Define a function to load and trim audio
def load_and_trim_audio(file_path, top_db=30):
    # Load audio file
    y, sr = librosa.load(file_path)
    # Trim silence
    trimmed_y, _ = librosa.effects.trim(y, top_db=top_db)
    return trimmed_y

# %%
X_trimmed = load_and_trim_audio(audio_data, top_db=30)

ipd.Audio(X_trimmed, rate=22000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
# plotting the sampled signal
librosa.display.waveshow(X_trimmed, sr=sr)

# %% [markdown]
# ### Spectrogram

# %%
# x: numpy array
X = librosa.stft(X_trimmed)
# converting into energy levels(dB)
Xdb = librosa.amplitude_to_db(abs(X))

plt.figure(figsize=(20, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %% [markdown]
# ### Display in log-frequency<a id='Display_in_log-frequency'></a>

# %%
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')

# %% [markdown]
# ### Down Sampling Test<a id='Down_Sampling_Test'></a>

# %%
# If you need to downsample the audio
desired_sr = 10000  # For example, to downsample to 1 kHz
x_downsampled = librosa.resample(X_trimmed, orig_sr=sr, target_sr=desired_sr)

# %%
ipd.Audio(x_downsampled, rate=5000) # play downsampled file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### MFCC, Chroma, Mel Test<a id='MFCC,_Chroma,_Mel_Test'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Load the audio file
# audio_path = f'{sound_path}/ravdess-data/Actor_01/03-01-01-01-01-01-01.wav'
# y, sr = librosa.load(audio_path)

# Extract MFCC
mfcc = librosa.feature.mfcc(y=X_trimmed, sr=sr, n_mfcc=20)
delta_mfccs = librosa.feature.delta(mfcc)
delta2_mfccs = librosa.feature.delta(mfcc, order=2)

# Plot original MFCC
plt.subplot(3, 1, 1)  # 3 rows, 1 column, 1st subplot
librosa.display.specshow(mfcc, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')

# Plot Delta MFCC
plt.subplot(3, 1, 2)  # 3 rows, 1 column, 2nd subplot
librosa.display.specshow(delta_mfccs, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Delta MFCC')

# Plot Delta-Delta MFCC
plt.subplot(3, 1, 3)  # 3 rows, 1 column, 3rd subplot
librosa.display.specshow(delta2_mfccs, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Delta-Delta MFCC')

plt.tight_layout()  # Adjust layout

# Extract Chroma
chroma = librosa.feature.chroma_stft(y=X_trimmed, sr=sr)
# Display Chroma
plt.figure(figsize=(10, 4))
librosa.display.specshow(chroma, y_axis='chroma', x_axis='time')
plt.colorbar()
plt.title('Chroma')
plt.tight_layout()
plt.show()

# Extract Mel Spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=X_trimmed, sr=sr)
# Display Mel Spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(mel_spectrogram, ref=np.max),
                         y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Creating a dataframe<a id='Creating_a_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# ### Helper functions

# %%
# Path to sound files RAVDESS
file_pattern = f'{sound_path}/ravdess-data/Actor_*/*.wav'

# Path to sound files CREMA-D
file_pattern_c = f'{sound_path}/CREMA-D/*.wav'

# Path to sound files CREMA-D
file_pattern_t = f'{sound_path}/TESS/*/*.wav'

# Extracts orginial file name as a helper to other functions
def extract_original_filename(filename):
    return filename.split('_part_')[0]

# Define a function to load and trim audio
def load_and_trim_audio(file_path, top_db=20):
    # Load audio file
    y, sr = librosa.load(file_path)
    # Trim silence
    trimmed_y, _ = librosa.effects.trim(y, top_db=top_db)
    return trimmed_y

# Define a function to load and trim audio for CREMA-D
def load_and_trim_audio_c(file_path, top_db=20):
    # Load audio file
    y, sr = librosa.load(file_path)
    # Trim silence
    trimmed_y, _ = librosa.effects.trim(y, top_db=top_db)
    return trimmed_y

# Define a function to load and trim audio for TESS
def load_and_trim_audio_t(file_path, top_db=20):
    # Load audio file
    y, sr = librosa.load(file_path)
    # Trim silence
    trimmed_y, _ = librosa.effects.trim(y, top_db=top_db)
    return trimmed_y

# Determines if split part is silent for another function to drop
def is_silent(y, threshold=0.001):
    return np.std(y) < threshold

# Define the determine_modality function
def determine_modality(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[0].rstrip('.wav'))
        if number % 3 == 1:
            return 1
        elif number % 3 == 2:
            return 2
        else:
            return 3
    except Exception as e:
        # print(f"Error in determine_modality: {e}")
        return 'Unknown'

# Define the determine_voice_channel function
def determine_voice_channel(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[1].rstrip('.wav'))
        return 1 if number % 2 == 1 else 2
    except Exception as e:
        # print(f"Error in determine_voice_channel: {e}")
        return 'Unknown'


# Define the dertermine_emotion function for RAVDESS
def determine_emotion(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[2].rstrip('.wav'))
        if number % 8 == 1:
            return 1
        elif number % 8 == 2:
            return 2
        elif number % 8 == 3:
            return 3
        elif number % 8 == 4:
            return 4
        elif number % 8 == 5:
            return 5
        elif number % 8 == 6:
            return 6
        elif number % 8 == 7:
            return 7
        else:
            return 8
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'

# Define the dertermine_emotion function for CREMA-D
def determine_emotion_c(filename):
    try:
        chars = extract_original_filename(filename).split('_')[2].rstrip('.wav')
        if chars == 'ANG':
            return 'anger'
        elif chars == 'DIS':
            return 'disgust'
        elif chars == 'FEA':
            return 'fearful'
        elif chars == 'HAP':
            return 'happy'
        elif chars == 'NEU':
            return 'neutral'
        else:
            return 'sad'
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'
    
# Define the dertermine_emotion function for TESS
def determine_emotion_t(filename):
    try:
        chars = extract_original_filename(filename).split('_')[2].rstrip('.wav')
        if chars == 'angry':
            return 'angry'
        elif chars == 'disgust':
            return 'disgust'
        elif chars == 'fear':
            return 'fear'
        elif chars == 'happy':
            return 'happy'
        elif chars == 'neutral':
            return 'neutral'
        elif chars == 'ps':
            return 'surprise'
        else:
            return 'sad'
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'

# Define the determine_intensity function for RAVDESS
def determine_intensity(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[3].rstrip('.wav'))
        return 1 if number % 2 == 1 else 2
    except Exception as e:
        # print(f"Error in determine_intensity: {e}")
        return 'Unknown'
    
# Define the determine_intensity function for CREMA-D
def determine_intensity_c(filename):
    try:
        chars = extract_original_filename(filename).split('_')[3].rstrip('.wav')
        if chars == 'LO':
            return 'LO'
        elif chars == 'MD':
            return 'MD'
        elif chars == 'HI':
            return 'HI'
        else:
            return 'XX'
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'

# Define the determine_statement function for RAVDESS
def determine_statement(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[4].rstrip('.wav'))
        return 1 if number % 2 == 1 else 2
    except Exception as e:
        # print(f"Error in determine_statement: {e}")
        return 'Unknown'

# Define the determine_statement function for CREMA-D
def determine_statement_c(filename):
    try:
        chars = extract_original_filename(filename).split('_')[1].rstrip('.wav')
        if chars == 'IEO':
            return 'IEO'
        elif chars == 'TIE':
            return 'TIE'
        elif chars == 'IOM':
            return 'IOM'
        elif chars == 'IWW':
            return 'IWW'
        elif chars == 'TAI':
            return 'TAI'
        elif chars == 'MTI':
            return 'MTI'
        elif chars == 'IWL':
            return 'IWL'
        elif chars == 'ITH':
            return 'ITH'
        elif chars == 'DFA':
            return 'DFA' 
        elif chars == 'ITS':
            return 'ITS' 
        elif chars == 'TSI':
            return 'TSI'        
        else:
            return 'WSI'
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'

# Define the determine_repetition function
def determine_repetition(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[5].rstrip('.wav'))
        return 1 if number % 2 == 1 else 2
    except Exception as e:
        # print(f"Error in determine_repetition: {e}")
        return 'Unknown'
    
# Define the determine_gender function
def determine_gender(filename):
    try:
        number = int(extract_original_filename(filename).split('-')[6].rstrip('.wav'))
        return 1 if number % 2 == 1 else 2
    except Exception as e:
        # print(f"Error in determine_gender: {e}")
        return 'Unknown'
    
# Define the dertermine_age_cat function for TESS
def determine_age_cat(filename):
    try:
        chars = extract_original_filename(filename).split('_')[0].rstrip('.wav')
        if chars == 'OAF':
            return 'old'
        else:
            return 'young'
    except Exception as e:
        # print(f"Error in determine_emotion: {e}")
        return 'Unknown'

def split_and_process(file_path):
    y, sr = librosa.load(file_path, sr=None)
    segment_length = len(y) // 3  # Adjust number of segments as needed, current is 3

    segments_data = []
    for i in range(3):  # Adjust number of segments as needed, current is 3
        start = i * segment_length
        end = None if i == 2 else (i + 1) * segment_length  # Adjust number of segments as needed, current is 3
        segment = y[start:end]

        modified_filename = f"{os.path.basename(file_path).rstrip('.wav')}_part_{chr(97 + i)}.wav"

        if is_silent(segment, threshold=0.001):
            silent_data.append({'filename': modified_filename, 'is_silent': True})
            continue  # Skip processing this segment

        features = extract_features(segment, sr, modified_filename)
        segments_data.append(features)

    return segments_data

# %% [markdown]
# ### RAVDESS dataframe<a id='RAVDESS_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Empty data set
data = []

# For loop to iterate over files
for file_path in glob.glob(file_pattern):
    try:
        # Extract just the .wav file name
        filename = os.path.basename(file_path)
        
        # Load each individual file
        y = load_and_trim_audio(file_path)
        
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T
        delta_mfccs = librosa.feature.delta(mfcc).T
        delta2_mfccs = librosa.feature.delta(mfcc, order=2).T
        chroma = librosa.feature.chroma_stft(y=y, sr=sr).T
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr).T
        spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr).T
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr).T
        roll_off = librosa.feature.spectral_rolloff(y=y, sr=sr).T
        rms = librosa.feature.rms(y=y).T
        zero_cr = librosa.feature.zero_crossing_rate(y=y).T
    
        features = {
            'filename': filename,
            'modality': determine_modality(filename),
            'vocal_channel': determine_voice_channel(filename),
            'emotion': determine_emotion(filename),
            'voice_intensity': determine_intensity(filename),
            'statement': determine_statement(filename),
            'statement_repetition': determine_repetition(filename),
            'actor_gender': determine_gender(filename),
            'mfcc_mean': mfcc.mean().mean(),
            'mfcc_max': mfcc.max().mean(),
            'mfcc_min': mfcc.min().mean(),
            'mfcc_median': np.median(mfcc).mean(),
            'mfcc_std': np.std(mfcc).mean(),
            'mfcc_skew': scipy.stats.skew(mfcc).mean(),
            'mfcc_kurtosis': scipy.stats.kurtosis(mfcc).mean(),
            'mfcc_delta_mean': delta_mfccs.mean().mean(),
            'mfcc_delta_max': delta_mfccs.max().mean(),
            'mfcc_delta_min': delta_mfccs.min().mean(),
            'mfcc_delta_median': np.median(delta_mfccs).mean(),
            'mfcc_delta_std': np.std(delta_mfccs).mean(),
            'mfcc_delta_skew': scipy.stats.skew(delta_mfccs).mean(),
            'mfcc_delta_kurtosis': scipy.stats.kurtosis(delta_mfccs).mean(),
            'mfcc_delta2_mean': delta2_mfccs.mean().mean(),
            'mfcc_delta2_max': delta2_mfccs.max().mean(),
            'mfcc_delta2_min': delta2_mfccs.min().mean(),
            'mfcc_delta2_median': np.median(delta2_mfccs).mean(),
            'mfcc_delta2_std': np.std(delta2_mfccs).mean(),
            'mfcc_delta2_skew': scipy.stats.skew(delta2_mfccs).mean(),
            'mfcc_delta2_kurtosis': scipy.stats.kurtosis(delta2_mfccs).mean(),
            'chroma_mean': chroma.mean().mean(),
            'chroma_min': chroma.min().mean(),
#            'chroma_max': chroma.max().mean(),    # always returned a 1
            'chroma_median': np.median(chroma).mean(),
            'chroma_std': np.std(chroma).mean(),
            'chroma_skew': scipy.stats.skew(chroma).mean(),
            'chroma_kurtosis': scipy.stats.kurtosis(chroma).mean(),
            'mel_mean': mel_spectrogram.mean().mean(),
            'mel_max': mel_spectrogram.max().mean(),
            'mel_min': mel_spectrogram.min().mean(),
            'mel_median': np.median(mel_spectrogram).mean(),
            'mel_std': np.std(mel_spectrogram).mean(),
            'mel_skew': scipy.stats.skew(mel_spectrogram).mean(),
            'mel_kurtosis': scipy.stats.kurtosis(mel_spectrogram).mean(),
            'contrast_mean': spectral_contrast.mean().mean(),
            'contrast_max': spectral_contrast.max().mean(),
            'contrast_min': spectral_contrast.min().mean(),
            'contrast_median': np.median(spectral_contrast).mean(),
            'contrast_std': np.std(spectral_contrast).mean(),
            'contrast_skew': scipy.stats.skew(spectral_contrast).mean(),
            'contrast_kurtosis': scipy.stats.kurtosis(spectral_contrast).mean(),
            'centroid_mean': centroid.mean().mean(),
            'centroid_max': centroid.max().mean(),
            'centroid_min': centroid.min().mean(),
            'centroid_median': np.median(centroid).mean(),
            'centroid_std': np.std(centroid).mean(),
            'centroid_skew': scipy.stats.skew(centroid).mean(),
            'centroid_kurtosis': scipy.stats.kurtosis(centroid).mean(),
            'roll_off_mean': roll_off.mean().mean(),
            'roll_off_max': roll_off.max().mean(),
            'roll_off_min': roll_off.min().mean(),
            'roll_off_median': np.median(roll_off).mean(),
            'roll_off_std': np.std(roll_off).mean(),
            'roll_off_skew': scipy.stats.skew(roll_off).mean(),
            'roll_off_kurtosis': scipy.stats.kurtosis(roll_off).mean(),
            'rms_mean': rms.mean().mean(),
            'rms_max': rms.max().mean(),
            'rms_min': rms.min().mean(),
            'rms_median': np.median(rms).mean(),
            'rms_std': np.std(rms).mean(),
            'rms_skew': scipy.stats.skew(rms).mean(),
            'rms_kurtosis': scipy.stats.kurtosis(rms).mean(),
            'zero_cr_mean': zero_cr.mean().mean(),
            'zero_cr_max': zero_cr.max().mean(),
            'zero_cr_min': zero_cr.min().mean(),
            'zero_cr_median': np.median(zero_cr).mean(),
            'zero_cr_std': np.std(zero_cr).mean(),
            'zero_cr_skew': scipy.stats.skew(zero_cr).mean(),
            'zero_cr_kurtosis': scipy.stats.kurtosis(zero_cr).mean(),
                     
        }

        data.append(features)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# for file_path in glob.glob(file_pattern):
#     try:
#         segments_features = split_and_process(file_path)
#         data.extend(segments_features)
#     except Exception as e:
#         print(f"Error processing file {file_path}: {e}")

# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df.head())
# Out:
#                    filename  modality  vocal_channel  emotion  \
# 0  03-01-01-01-01-01-01.wav         3              1        1
# 1  03-01-01-01-01-02-01.wav         3              1        1
# 2  03-01-01-01-02-01-01.wav         3              1        1
# 3  03-01-01-01-02-02-01.wav         3              1        1
# 4  03-01-02-01-01-01-01.wav         3              1        2
#
#    voice_intensity  statement  statement_repetition  actor_gender  mfcc_mean  \
# 0                1          1                     1             1 -16.392443
# 1                1          1                     2             1 -16.195488
# 2                1          2                     1             1 -15.760641
# 3                1          2                     2             1 -16.046278
# 4                1          1                     1             1 -16.582544
#
#      mfcc_max  ...   rms_std  rms_skew  rms_kurtosis  zero_cr_mean  \
# 0  202.985016  ...  0.002752  0.523488     -0.223807      0.071506
# 1  193.519836  ...  0.003002  0.472005     -0.447499      0.063912
# 2  209.642426  ...  0.003825  1.126351      0.754771      0.086652
# 3  215.376984  ...  0.004013  1.583204      1.841371      0.088229
# 4  205.080627  ...  0.002391  1.028021      0.677945      0.082396
#
#    zero_cr_max  zero_cr_min  zero_cr_median  zero_cr_std  zero_cr_skew  \
# 0     0.208984     0.023438        0.046875     0.049214      1.349598
# 1     0.183105     0.019531        0.048340     0.042300      1.347601
# 2     0.424316     0.014648        0.048340     0.091483      2.158822
# 3     0.406250     0.013184        0.047852     0.093873      1.803562
# 4     0.374512     0.018555        0.047852     0.076891      2.038556
#
#    zero_cr_kurtosis
# 0          0.792986
# 1          0.843776
# 2          4.017514
# 3          2.245144
# 4          3.821344
#
# [5 rows x 77 columns]

# %% [markdown]
# ### CREMA-D dataframe<a id='CREMA-D_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Empty data set
data_c = []

# For loop to iterate over files
for file_path in glob.glob(file_pattern_c):
    try:
        # Extract just the .wav file name
        filename = os.path.basename(file_path)
        
        # Load each individual file
        y = load_and_trim_audio_c(file_path)
        
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T
        delta_mfccs = librosa.feature.delta(mfcc).T
        delta2_mfccs = librosa.feature.delta(mfcc, order=2).T
        chroma = librosa.feature.chroma_stft(y=y, sr=sr).T
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr).T
        spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr).T
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr).T
        roll_off = librosa.feature.spectral_rolloff(y=y, sr=sr).T
        rms = librosa.feature.rms(y=y).T
        zero_cr = librosa.feature.zero_crossing_rate(y=y).T
    
        features = {
            'filename': filename,
            'statement': determine_statement_c(filename),
            'emotion': determine_emotion_c(filename),
            'voice_intensity': determine_intensity_c(filename),
            'mfcc_mean': mfcc.mean().mean(),
            'mfcc_max': mfcc.max().mean(),
            'mfcc_min': mfcc.min().mean(),
            'mfcc_median': np.median(mfcc).mean(),
            'mfcc_std': np.std(mfcc).mean(),
            'mfcc_skew': scipy.stats.skew(mfcc).mean(),
            'mfcc_kurtosis': scipy.stats.kurtosis(mfcc).mean(),
            'mfcc_delta_mean': delta_mfccs.mean().mean(),
            'mfcc_delta_max': delta_mfccs.max().mean(),
            'mfcc_delta_min': delta_mfccs.min().mean(),
            'mfcc_delta_median': np.median(delta_mfccs).mean(),
            'mfcc_delta_std': np.std(delta_mfccs).mean(),
            'mfcc_delta_skew': scipy.stats.skew(delta_mfccs).mean(),
            'mfcc_delta_kurtosis': scipy.stats.kurtosis(delta_mfccs).mean(),
            'mfcc_delta2_mean': delta2_mfccs.mean().mean(),
            'mfcc_delta2_max': delta2_mfccs.max().mean(),
            'mfcc_delta2_min': delta2_mfccs.min().mean(),
            'mfcc_delta2_median': np.median(delta2_mfccs).mean(),
            'mfcc_delta2_std': np.std(delta2_mfccs).mean(),
            'mfcc_delta2_skew': scipy.stats.skew(delta2_mfccs).mean(),
            'mfcc_delta2_kurtosis': scipy.stats.kurtosis(delta2_mfccs).mean(),
            'chroma_mean': chroma.mean().mean(),
            'chroma_min': chroma.min().mean(),
#            'chroma_max': chroma.max().mean(),    # always returned a 1
            'chroma_median': np.median(chroma).mean(),
            'chroma_std': np.std(chroma).mean(),
            'chroma_skew': scipy.stats.skew(chroma).mean(),
            'chroma_kurtosis': scipy.stats.kurtosis(chroma).mean(),
            'mel_mean': mel_spectrogram.mean().mean(),
            'mel_max': mel_spectrogram.max().mean(),
            'mel_min': mel_spectrogram.min().mean(),
            'mel_median': np.median(mel_spectrogram).mean(),
            'mel_std': np.std(mel_spectrogram).mean(),
            'mel_skew': scipy.stats.skew(mel_spectrogram).mean(),
            'mel_kurtosis': scipy.stats.kurtosis(mel_spectrogram).mean(),
            'contrast_mean': spectral_contrast.mean().mean(),
            'contrast_max': spectral_contrast.max().mean(),
            'contrast_min': spectral_contrast.min().mean(),
            'contrast_median': np.median(spectral_contrast).mean(),
            'contrast_std': np.std(spectral_contrast).mean(),
            'contrast_skew': scipy.stats.skew(spectral_contrast).mean(),
            'contrast_kurtosis': scipy.stats.kurtosis(spectral_contrast).mean(),
            'centroid_mean': centroid.mean().mean(),
            'centroid_max': centroid.max().mean(),
            'centroid_min': centroid.min().mean(),
            'centroid_median': np.median(centroid).mean(),
            'centroid_std': np.std(centroid).mean(),
            'centroid_skew': scipy.stats.skew(centroid).mean(),
            'centroid_kurtosis': scipy.stats.kurtosis(centroid).mean(),
            'roll_off_mean': roll_off.mean().mean(),
            'roll_off_max': roll_off.max().mean(),
            'roll_off_min': roll_off.min().mean(),
            'roll_off_median': np.median(roll_off).mean(),
            'roll_off_std': np.std(roll_off).mean(),
            'roll_off_skew': scipy.stats.skew(roll_off).mean(),
            'roll_off_kurtosis': scipy.stats.kurtosis(roll_off).mean(),
            'rms_mean': rms.mean().mean(),
            'rms_max': rms.max().mean(),
            'rms_min': rms.min().mean(),
            'rms_median': np.median(rms).mean(),
            'rms_std': np.std(rms).mean(),
            'rms_skew': scipy.stats.skew(rms).mean(),
            'rms_kurtosis': scipy.stats.kurtosis(rms).mean(),
            'zero_cr_mean': zero_cr.mean().mean(),
            'zero_cr_max': zero_cr.max().mean(),
            'zero_cr_min': zero_cr.min().mean(),
            'zero_cr_median': np.median(zero_cr).mean(),
            'zero_cr_std': np.std(zero_cr).mean(),
            'zero_cr_skew': scipy.stats.skew(zero_cr).mean(),
            'zero_cr_kurtosis': scipy.stats.kurtosis(zero_cr).mean(),
                     
        }

        data_c.append(features)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# Create DataFrame
df_c = pd.DataFrame(data_c)

# Display the DataFrame
print(df_c.head())
# Out:
# C:\Users\where\AppData\Roaming\Python\Python311\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# C:\Users\where\AppData\Local\Temp\ipykernel_21840\2682512078.py:34: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   'mfcc_skew': scipy.stats.skew(mfcc).mean(),
# C:\Users\where\AppData\Local\Temp\ipykernel_21840\2682512078.py:35: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   'mfcc_kurtosis': scipy.stats.kurtosis(mfcc).mean(),
#               filename statement  emotion voice_intensity  mfcc_mean  \
# 0  1001_DFA_ANG_XX.wav       DFA    anger              XX  -7.861806
# 1  1001_DFA_DIS_XX.wav       DFA  disgust              XX  -9.452926
# 2  1001_DFA_FEA_XX.wav       DFA  fearful              XX  -7.836610
# 3  1001_DFA_HAP_XX.wav       DFA    happy              XX  -7.816556
# 4  1001_DFA_NEU_XX.wav       DFA  neutral              XX  -9.037200
#
#      mfcc_max    mfcc_min  mfcc_median   mfcc_std  mfcc_skew  ...   rms_std  \
# 0  172.138824 -367.821381    -3.355731  45.420494  -0.083274  ...  0.048450
# 1  175.354660 -450.325592    -4.190086  53.548962   0.044376  ...  0.015989
# 2  138.946365 -321.096436    -3.260339  39.805393  -0.009055  ...  0.058515
# 3  159.304550 -369.911713    -3.084167  43.203659   0.120049  ...  0.044943
# 4  176.853989 -421.881042    -3.800208  51.701851   0.062062  ...  0.025147
#
#    rms_skew  rms_kurtosis  zero_cr_mean  zero_cr_max  zero_cr_min  \
# 0  0.566373     -0.510565      0.105326     0.266113     0.041504
# 1  0.909930      0.185061      0.108738     0.271973     0.043945
# 2  0.059786     -1.035065      0.103251     0.235840     0.040039
# 3  0.600728     -0.537000      0.094951     0.221680     0.034668
# 4  1.233218      0.494438      0.083362     0.187012     0.034668
#
#    zero_cr_median  zero_cr_std  zero_cr_skew  zero_cr_kurtosis
# 0        0.098877     0.046664      1.461352          2.607774
# 1        0.106201     0.051661      1.394082          2.008864
# 2        0.089355     0.046278      1.585550          1.822081
# 3        0.086914     0.042843      1.538277          2.198416
# 4        0.077393     0.035711      1.318870          1.428997
#
# [5 rows x 73 columns]

# %% [markdown]
# ### TESS dataframe<a id='TESS_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Empty data set
data_t = []

# For loop to iterate over files
for file_path in glob.glob(file_pattern_t):
    try:
        # Extract just the .wav file name
        filename = os.path.basename(file_path)
        
        # Load each individual file
        y = load_and_trim_audio_t(file_path)
                        
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T
        delta_mfccs = librosa.feature.delta(mfcc).T
        delta2_mfccs = librosa.feature.delta(mfcc, order=2).T
        chroma = librosa.feature.chroma_stft(y=y, sr=sr).T
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr).T
        spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr).T
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr).T
        roll_off = librosa.feature.spectral_rolloff(y=y, sr=sr).T
        rms = librosa.feature.rms(y=y).T
        zero_cr = librosa.feature.zero_crossing_rate(y=y).T
    
        features = {
            'filename': filename,
            'age category': determine_age_cat(filename),
            'emotion': determine_emotion_t(filename),
            'mfcc_mean': mfcc.mean().mean(),
            'mfcc_max': mfcc.max().mean(),
            'mfcc_min': mfcc.min().mean(),
            'mfcc_median': np.median(mfcc).mean(),
            'mfcc_std': np.std(mfcc).mean(),
            'mfcc_skew': scipy.stats.skew(mfcc).mean(),
            'mfcc_kurtosis': scipy.stats.kurtosis(mfcc).mean(),
            'mfcc_delta_mean': delta_mfccs.mean().mean(),
            'mfcc_delta_max': delta_mfccs.max().mean(),
            'mfcc_delta_min': delta_mfccs.min().mean(),
            'mfcc_delta_median': np.median(delta_mfccs).mean(),
            'mfcc_delta_std': np.std(delta_mfccs).mean(),
            'mfcc_delta_skew': scipy.stats.skew(delta_mfccs).mean(),
            'mfcc_delta_kurtosis': scipy.stats.kurtosis(delta_mfccs).mean(),
            'mfcc_delta2_mean': delta2_mfccs.mean().mean(),
            'mfcc_delta2_max': delta2_mfccs.max().mean(),
            'mfcc_delta2_min': delta2_mfccs.min().mean(),
            'mfcc_delta2_median': np.median(delta2_mfccs).mean(),
            'mfcc_delta2_std': np.std(delta2_mfccs).mean(),
            'mfcc_delta2_skew': scipy.stats.skew(delta2_mfccs).mean(),
            'mfcc_delta2_kurtosis': scipy.stats.kurtosis(delta2_mfccs).mean(),
            'chroma_mean': chroma.mean().mean(),
            'chroma_min': chroma.min().mean(),
#            'chroma_max': chroma.max().mean(),    # always returned a 1
            'chroma_median': np.median(chroma).mean(),
            'chroma_std': np.std(chroma).mean(),
            'chroma_skew': scipy.stats.skew(chroma).mean(),
            'chroma_kurtosis': scipy.stats.kurtosis(chroma).mean(),
            'mel_mean': mel_spectrogram.mean().mean(),
            'mel_max': mel_spectrogram.max().mean(),
            'mel_min': mel_spectrogram.min().mean(),
            'mel_median': np.median(mel_spectrogram).mean(),
            'mel_std': np.std(mel_spectrogram).mean(),
            'mel_skew': scipy.stats.skew(mel_spectrogram).mean(),
            'mel_kurtosis': scipy.stats.kurtosis(mel_spectrogram).mean(),
            'contrast_mean': spectral_contrast.mean().mean(),
            'contrast_max': spectral_contrast.max().mean(),
            'contrast_min': spectral_contrast.min().mean(),
            'contrast_median': np.median(spectral_contrast).mean(),
            'contrast_std': np.std(spectral_contrast).mean(),
            'contrast_skew': scipy.stats.skew(spectral_contrast).mean(),
            'contrast_kurtosis': scipy.stats.kurtosis(spectral_contrast).mean(),
            'centroid_mean': centroid.mean().mean(),
            'centroid_max': centroid.max().mean(),
            'centroid_min': centroid.min().mean(),
            'centroid_median': np.median(centroid).mean(),
            'centroid_std': np.std(centroid).mean(),
            'centroid_skew': scipy.stats.skew(centroid).mean(),
            'centroid_kurtosis': scipy.stats.kurtosis(centroid).mean(),
            'roll_off_mean': roll_off.mean().mean(),
            'roll_off_max': roll_off.max().mean(),
            'roll_off_min': roll_off.min().mean(),
            'roll_off_median': np.median(roll_off).mean(),
            'roll_off_std': np.std(roll_off).mean(),
            'roll_off_skew': scipy.stats.skew(roll_off).mean(),
            'roll_off_kurtosis': scipy.stats.kurtosis(roll_off).mean(),
            'rms_mean': rms.mean().mean(),
            'rms_max': rms.max().mean(),
            'rms_min': rms.min().mean(),
            'rms_median': np.median(rms).mean(),
            'rms_std': np.std(rms).mean(),
            'rms_skew': scipy.stats.skew(rms).mean(),
            'rms_kurtosis': scipy.stats.kurtosis(rms).mean(),
            'zero_cr_mean': zero_cr.mean().mean(),
            'zero_cr_max': zero_cr.max().mean(),
            'zero_cr_min': zero_cr.min().mean(),
            'zero_cr_median': np.median(zero_cr).mean(),
            'zero_cr_std': np.std(zero_cr).mean(),
            'zero_cr_skew': scipy.stats.skew(zero_cr).mean(),
            'zero_cr_kurtosis': scipy.stats.kurtosis(zero_cr).mean(),
                     
        }

        data_t.append(features)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        
# Create DataFrame
df_t = pd.DataFrame(data_t)

# Display the DataFrame
print(df_t.head())
# Out:
# Processed OAF_back_angry.wav
# Processed OAF_bar_angry.wav
# Processed OAF_base_angry.wav
# Processed OAF_bath_angry.wav
# Processed OAF_bean_angry.wav
# Processed OAF_beg_angry.wav
# Processed OAF_bite_angry.wav
# Processed OAF_boat_angry.wav
# Processed OAF_bone_angry.wav
# Processed OAF_book_angry.wav
# Processed OAF_bought_angry.wav
# Processed OAF_burn_angry.wav
# Processed OAF_cab_angry.wav
# Processed OAF_calm_angry.wav
# Processed OAF_came_angry.wav
# Processed OAF_cause_angry.wav
# Processed OAF_chain_angry.wav
# Processed OAF_chair_angry.wav
# Processed OAF_chalk_angry.wav
# Processed OAF_chat_angry.wav
# Processed OAF_check_angry.wav
# Processed OAF_cheek_angry.wav
# Processed OAF_chief_angry.wav
# Processed OAF_choice_angry.wav
# Processed OAF_cool_angry.wav
# Processed OAF_dab_angry.wav
# Processed OAF_date_angry.wav
# Processed OAF_dead_angry.wav
# Processed OAF_death_angry.wav
# Processed OAF_deep_angry.wav
# Processed OAF_dime_angry.wav
# Processed OAF_dip_angry.wav
# Processed OAF_ditch_angry.wav
# Processed OAF_dodge_angry.wav
# Processed OAF_dog_angry.wav
# Processed OAF_doll_angry.wav
# Processed OAF_door_angry.wav
# Processed OAF_fail_angry.wav
# Processed OAF_fall_angry.wav
# Processed OAF_far_angry.wav
# Processed OAF_fat_angry.wav
# Processed OAF_fit_angry.wav
# Processed OAF_five_angry.wav
# Processed OAF_food_angry.wav
# Processed OAF_gap_angry.wav
# Processed OAF_gas_angry.wav
# Processed OAF_gaze_angry.wav
# Processed OAF_germ_angry.wav
# Processed OAF_get_angry.wav
# Processed OAF_gin_angry.wav
# Processed OAF_goal_angry.wav
# Processed OAF_good_angry.wav
# Processed OAF_goose_angry.wav
# Processed OAF_gun_angry.wav
# Processed OAF_half_angry.wav
# Processed OAF_hall_angry.wav
# Processed OAF_hash_angry.wav
# Processed OAF_hate_angry.wav
# Processed OAF_have_angry.wav
# Processed OAF_haze_angry.wav
# Processed OAF_hire_angry.wav
# Processed OAF_hit_angry.wav
# Processed OAF_hole_angry.wav
# Processed OAF_home_angry.wav
# Processed OAF_hurl_angry.wav
# Processed OAF_hush_angry.wav
# Processed OAF_jail_angry.wav
# Processed OAF_jar_angry.wav
# Processed OAF_join_angry.wav
# Processed OAF_judge_angry.wav
# Processed OAF_jug_angry.wav
# Processed OAF_juice_angry.wav
# Processed OAF_keen_angry.wav
# Processed OAF_keep_angry.wav
# Processed OAF_keg_angry.wav
# Processed OAF_kick_angry.wav
# Processed OAF_kill_angry.wav
# Processed OAF_king_angry.wav
# Processed OAF_kite_angry.wav
# Processed OAF_knock_angry.wav
# Processed OAF_late_angry.wav
# Processed OAF_laud_angry.wav
# Processed OAF_lean_angry.wav
# Processed OAF_learn_angry.wav
# Processed OAF_lease_angry.wav
# Processed OAF_lid_angry.wav
# Processed OAF_life_angry.wav
# Processed OAF_limb_angry.wav
# Processed OAF_live_angry.wav
# Processed OAF_loaf_angry.wav
# Processed OAF_long_angry.wav
# Processed OAF_lore_angry.wav
# Processed OAF_lose_angry.wav
# Processed OAF_lot_angry.wav
# Processed OAF_love_angry.wav
# Processed OAF_luck_angry.wav
# Processed OAF_make_angry.wav
# Processed OAF_match_angry.wav
# Processed OAF_merge_angry.wav
# Processed OAF_mess_angry.wav
# Processed OAF_met_angry.wav
# Processed OAF_mill_angry.wav
# Processed OAF_mob_angry.wav
# Processed OAF_mode_angry.wav
# Processed OAF_mood_angry.wav
# Processed OAF_moon_angry.wav
# Processed OAF_mop_angry.wav
# Processed OAF_mouse_angry.wav
# Processed OAF_nag_angry.wav
# Processed OAF_name_angry.wav
# Processed OAF_near_angry.wav
# Processed OAF_neat_angry.wav
# Processed OAF_nice_angry.wav
# Processed OAF_note_angry.wav
# Processed OAF_numb_angry.wav
# Processed OAF_pad_angry.wav
# Processed OAF_page_angry.wav
# Processed OAF_pain_angry.wav
# Processed OAF_pass_angry.wav
# Processed OAF_pearl_angry.wav
# Processed OAF_peg_angry.wav
# Processed OAF_perch_angry.wav
# Processed OAF_phone_angry.wav
# Processed OAF_pick_angry.wav
# Processed OAF_pike_angry.wav
# Processed OAF_pole_angry.wav
# Processed OAF_pool_angry.wav
# Processed OAF_puff_angry.wav
# Processed OAF_rag_angry.wav
# Processed OAF_raid_angry.wav
# Processed OAF_rain_angry.wav
# Processed OAF_raise_angry.wav
# Processed OAF_rat_angry.wav
# Processed OAF_reach_angry.wav
# Processed OAF_read_angry.wav
# Processed OAF_red_angry.wav
# Processed OAF_ring_angry.wav
# Processed OAF_ripe_angry.wav
# Processed OAF_road_angry.wav
# Processed OAF_room_angry.wav
# Processed OAF_rose_angry.wav
# Processed OAF_rot_angry.wav
# Processed OAF_rough_angry.wav
# Processed OAF_rush_angry.wav
# Processed OAF_said_angry.wav
# Processed OAF_sail_angry.wav
# Processed OAF_search_angry.wav
# Processed OAF_seize_angry.wav
# Processed OAF_sell_angry.wav
# Processed OAF_shack_angry.wav
# Processed OAF_shall_angry.wav
# Processed OAF_shawl_angry.wav
# Processed OAF_sheep_angry.wav
# Processed OAF_shirt_angry.wav
# Processed OAF_should_angry.wav
# Processed OAF_shout_angry.wav
# Processed OAF_size_angry.wav
# Processed OAF_soap_angry.wav
# Processed OAF_soup_angry.wav
# Processed OAF_sour_angry.wav
# Processed OAF_south_angry.wav
# Processed OAF_sub_angry.wav
# Processed OAF_such_angry.wav
# Processed OAF_sure_angry.wav
# Processed OAF_take_angry.wav
# Processed OAF_talk_angry.wav
# Processed OAF_tape_angry.wav
# Processed OAF_team_angry.wav
# Processed OAF_tell_angry.wav
# Processed OAF_thin_angry.wav
# Processed OAF_third_angry.wav
# Processed OAF_thought_angry.wav
# Processed OAF_thumb_angry.wav
# Processed OAF_time_angry.wav
# Processed OAF_tip_angry.wav
# Processed OAF_tire_angry.wav
# Processed OAF_ton_angry.wav
# Processed OAF_tool_angry.wav
# Processed OAF_tough_angry.wav
# Processed OAF_turn_angry.wav
# Processed OAF_vine_angry.wav
# Processed OAF_voice_angry.wav
# Processed OAF_void_angry.wav
# Processed OAF_vote_angry.wav
# Processed OAF_wag_angry.wav
# Processed OAF_walk_angry.wav
# Processed OAF_wash_angry.wav
# Processed OAF_week_angry.wav
# Processed OAF_wheat_angry.wav
# Processed OAF_when_angry.wav
# Processed OAF_which_angry.wav
# Processed OAF_whip_angry.wav
# Processed OAF_white_angry.wav
# Processed OAF_wife_angry.wav
# Processed OAF_wire_angry.wav
# Processed OAF_witch_angry.wav
# Processed OAF_yearn_angry.wav
# Processed OAF_yes_angry.wav
# Processed OAF_young_angry.wav
# Processed OAF_youth_angry.wav
# Processed OAF_back_disgust.wav
# Processed OAF_bar_disgust.wav
# Processed OAF_base_disgust.wav
# Processed OAF_bath_disgust.wav
# Processed OAF_bean_disgust.wav
# Processed OAF_beg_disgust.wav
# Processed OAF_bite_disgust.wav
# Processed OAF_boat_disgust.wav
# Processed OAF_bone_disgust.wav
# Processed OAF_book_disgust.wav
# Processed OAF_bought_disgust.wav
# Processed OAF_burn_disgust.wav
# Processed OAF_cab_disgust.wav
# Processed OAF_calm_disgust.wav
# Processed OAF_came_disgust.wav
# Processed OAF_cause_disgust.wav
# Processed OAF_chain_disgust.wav
# Processed OAF_chair_disgust.wav
# Processed OAF_chalk_disgust.wav
# Processed OAF_chat_disgust.wav
# Processed OAF_check_disgust.wav
# Processed OAF_cheek_disgust.wav
# Processed OAF_chief_disgust.wav
# Processed OAF_choice_disgust.wav
# Processed OAF_cool_disgust.wav
# Processed OAF_dab_disgust.wav
# Processed OAF_date_disgust.wav
# Processed OAF_dead_disgust.wav
# Processed OAF_death_disgust.wav
# Processed OAF_deep_disgust.wav
# Processed OAF_dime_disgust.wav
# Processed OAF_dip_disgust.wav
# Processed OAF_ditch_disgust.wav
# Processed OAF_dodge_disgust.wav
# Processed OAF_dog_disgust.wav
# Processed OAF_doll_disgust.wav
# Processed OAF_door_disgust.wav
# Processed OAF_fail_disgust.wav
# Processed OAF_fall_disgust.wav
# Processed OAF_far_disgust.wav
# Processed OAF_fat_disgust.wav
# Processed OAF_fit_disgust.wav
# Processed OAF_five_disgust.wav
# Processed OAF_food_disgust.wav
# Processed OAF_gap_disgust.wav
# Processed OAF_gas_disgust.wav
# Processed OAF_gaze_disgust.wav
# Processed OAF_germ_disgust.wav
# Processed OAF_get_disgust.wav
# Processed OAF_gin_disgust.wav
# Processed OAF_goal_disgust.wav
# Processed OAF_good_disgust.wav
# Processed OAF_goose_disgust.wav
# Processed OAF_gun_disgust.wav
# Processed OAF_half_disgust.wav
# Processed OAF_hall_disgust.wav
# Processed OAF_hash_disgust.wav
# Processed OAF_hate_disgust.wav
# Processed OAF_have_disgust.wav
# Processed OAF_haze_disgust.wav
# Processed OAF_hire_disgust.wav
# Processed OAF_hit_disgust.wav
# Processed OAF_hole_disgust.wav
# Processed OAF_home_disgust.wav
# Processed OAF_hurl_disgust.wav
# Processed OAF_hush_disgust.wav
# Processed OAF_jail_disgust.wav
# Processed OAF_jar_disgust.wav
# Processed OAF_join_disgust.wav
# Processed OAF_judge_disgust.wav
# Processed OAF_jug_disgust.wav
# Processed OAF_juice_disgust.wav
# Processed OAF_keen_disgust.wav
# Processed OAF_keep_disgust.wav
# Processed OAF_keg_disgust.wav
# Processed OAF_kick_disgust.wav
# Processed OAF_kill_disgust.wav
# Processed OAF_king_disgust.wav
# Processed OAF_kite_disgust.wav
# Processed OAF_knock_disgust.wav
# Processed OAF_late_disgust.wav
# Processed OAF_laud_disgust.wav
# Processed OAF_lean_disgust.wav
# Processed OAF_learn_disgust.wav
# Processed OAF_lease_disgust.wav
# Processed OAF_lid_disgust.wav
# Processed OAF_life_disgust.wav
# Processed OAF_limb_disgust.wav
# Processed OAF_live_disgust.wav
# Processed OAF_loaf_disgust.wav
# Processed OAF_long_disgust.wav
# Processed OAF_lore_disgust.wav
# Processed OAF_lose_disgust.wav
# Processed OAF_lot_disgust.wav
# Processed OAF_love_disgust.wav
# Processed OAF_luck_disgust.wav
# Processed OAF_make_disgust.wav
# Processed OAF_match_disgust.wav
# Processed OAF_merge_disgust.wav
# Processed OAF_mess_disgust.wav
# Processed OAF_met_disgust.wav
# Processed OAF_mill_disgust.wav
# Processed OAF_mob_disgust.wav
# Processed OAF_mode_disgust.wav
# Processed OAF_mood_disgust.wav
# Processed OAF_moon_disgust.wav
# Processed OAF_mop_disgust.wav
# Processed OAF_mouse_disgust.wav
# Processed OAF_nag_disgust.wav
# Processed OAF_name_disgust.wav
# Processed OAF_near_disgust.wav
# Processed OAF_neat_disgust.wav
# Processed OAF_nice_disgust.wav
# Processed OAF_note_disgust.wav
# Processed OAF_numb_disgust.wav
# Processed OAF_pad_disgust.wav
# Processed OAF_page_disgust.wav
# Processed OAF_pain_disgust.wav
# Processed OAF_pass_disgust.wav
# Processed OAF_pearl_disgust.wav
# Processed OAF_peg_disgust.wav
# Processed OAF_perch_disgust.wav
# Processed OAF_phone_disgust.wav
# Processed OAF_pick_disgust.wav
# Processed OAF_pike_disgust.wav
# Processed OAF_pole_disgust.wav
# Processed OAF_pool_disgust.wav
# Processed OAF_puff_disgust.wav
# Processed OAF_rag_disgust.wav
# Processed OAF_raid_disgust.wav
# Processed OAF_rain_disgust.wav
# Processed OAF_raise_disgust.wav
# Processed OAF_rat_disgust.wav
# Processed OAF_reach_disgust.wav
# Processed OAF_read_disgust.wav
# Processed OAF_red_disgust.wav
# Processed OAF_ring_disgust.wav
# Processed OAF_ripe_disgust.wav
# Processed OAF_road_disgust.wav
# Processed OAF_room_disgust.wav
# Processed OAF_rose_disgust.wav
# Processed OAF_rot_disgust.wav
# Processed OAF_rough_disgust.wav
# Processed OAF_rush_disgust.wav
# Processed OAF_said_disgust.wav
# Processed OAF_sail_disgust.wav
# Processed OAF_search_disgust.wav
# Processed OAF_seize_disgust.wav
# Processed OAF_sell_disgust.wav
# Processed OAF_shack_disgust.wav
# Processed OAF_shall_disgust.wav
# Processed OAF_shawl_disgust.wav
# Processed OAF_sheep_disgust.wav
# Processed OAF_shirt_disgust.wav
# Processed OAF_should_disgust.wav
# Processed OAF_shout_disgust.wav
# Processed OAF_size_disgust.wav
# Processed OAF_soap_disgust.wav
# Processed OAF_soup_disgust.wav
# Processed OAF_sour_disgust.wav
# Processed OAF_south_disgust.wav
# Processed OAF_sub_disgust.wav
# Processed OAF_such_disgust.wav
# Processed OAF_sure_disgust.wav
# Processed OAF_take_disgust.wav
# Processed OAF_talk_disgust.wav
# Processed OAF_tape_disgust.wav
# Processed OAF_team_disgust.wav
# Processed OAF_tell_disgust.wav
# Processed OAF_thin_disgust.wav
# Processed OAF_third_disgust.wav
# Processed OAF_thought_disgust.wav
# Processed OAF_thumb_disgust.wav
# Processed OAF_time_disgust.wav
# Processed OAF_tip_disgust.wav
# Processed OAF_tire_disgust.wav
# Processed OAF_ton_disgust.wav
# Processed OAF_tool_disgust.wav
# Processed OAF_tough_disgust.wav
# Processed OAF_turn_disgust.wav
# Processed OAF_vine_disgust.wav
# Processed OAF_voice_disgust.wav
# Processed OAF_void_disgust.wav
# Processed OAF_vote_disgust.wav
# Processed OAF_wag_disgust.wav
# Processed OAF_walk_disgust.wav
# Processed OAF_wash_disgust.wav
# Processed OAF_week_disgust.wav
# Processed OAF_wheat_disgust.wav
# Processed OAF_when_disgust.wav
# Processed OAF_which_disgust.wav
# Processed OAF_whip_disgust.wav
# Processed OAF_white_disgust.wav
# Processed OAF_wife_disgust.wav
# Processed OAF_wire_disgust.wav
# Processed OAF_witch_disgust.wav
# Processed OAF_yearn_disgust.wav
# Processed OAF_yes_disgust.wav
# Processed OAF_young_disgust.wav
# Processed OAF_youth_disgust.wav
# Processed OAF_back_fear.wav
# Processed OAF_bar_fear.wav
# Processed OAF_base_fear.wav
# Processed OAF_bath_fear.wav
# Processed OAF_bean_fear.wav
# Processed OAF_beg_fear.wav
# Processed OAF_bite_fear.wav
# Processed OAF_boat_fear.wav
# Processed OAF_bone_fear.wav
# Processed OAF_book_fear.wav
# Processed OAF_bought_fear.wav
# Processed OAF_burn_fear.wav
# Processed OAF_cab_fear.wav
# Processed OAF_calm_fear.wav
# Processed OAF_came_fear.wav
# Processed OAF_cause_fear.wav
# Processed OAF_chain_fear.wav
# Processed OAF_chair_fear.wav
# Processed OAF_chalk_fear.wav
# Processed OAF_chat_fear.wav
# Processed OAF_check_fear.wav
# Processed OAF_cheek_fear.wav
# Processed OAF_chief_fear.wav
# Processed OAF_choice_fear.wav
# Processed OAF_cool_fear.wav
# Processed OAF_dab_fear.wav
# Processed OAF_date_fear.wav
# Processed OAF_dead_fear.wav
# Processed OAF_death_fear.wav
# Processed OAF_deep_fear.wav
# Processed OAF_dime_fear.wav
# Processed OAF_dip_fear.wav
# Processed OAF_ditch_fear.wav
# Processed OAF_dodge_fear.wav
# Processed OAF_dog_fear.wav
# Processed OAF_doll_fear.wav
# Processed OAF_door_fear.wav
# Processed OAF_fail_fear.wav
# Processed OAF_fall_fear.wav
# Processed OAF_far_fear.wav
# Processed OAF_fat_fear.wav
# Processed OAF_fit_fear.wav
# Processed OAF_five_fear.wav
# Processed OAF_food_fear.wav
# Processed OAF_gap_fear.wav
# Processed OAF_gas_fear.wav
# Processed OAF_gaze_fear.wav
# Processed OAF_germ_fear.wav
# Processed OAF_get_fear.wav
# Processed OAF_gin_fear.wav
# Processed OAF_goal_fear.wav
# Processed OAF_good_fear.wav
# Processed OAF_goose_fear.wav
# Processed OAF_gun_fear.wav
# Processed OAF_half_fear.wav
# Processed OAF_hall_fear.wav
# Processed OAF_hash_fear.wav
# Processed OAF_hate_fear.wav
# Processed OAF_have_fear.wav
# Processed OAF_haze_fear.wav
# Processed OAF_hire_fear.wav
# Processed OAF_hit_fear.wav
# Processed OAF_hole_fear.wav
# Processed OAF_home_fear.wav
# Processed OAF_hurl_fear.wav
# Processed OAF_hush_fear.wav
# Processed OAF_jail_fear.wav
# Processed OAF_jar_fear.wav
# Processed OAF_join_fear.wav
# Processed OAF_judge_fear.wav
# Processed OAF_jug_fear.wav
# Processed OAF_juice_fear.wav
# Processed OAF_keen_fear.wav
# Processed OAF_keep_fear.wav
# Processed OAF_keg_fear.wav
# Processed OAF_kick_fear.wav
# Processed OAF_kill_fear.wav
# Processed OAF_king_fear.wav
# Processed OAF_kite_fear.wav
# Processed OAF_knock_fear.wav
# Processed OAF_late_fear.wav
# Processed OAF_laud_fear.wav
# Processed OAF_lean_fear.wav
# Processed OAF_learn_fear.wav
# Processed OAF_lease_fear.wav
# Processed OAF_lid_fear.wav
# Processed OAF_life_fear.wav
# Processed OAF_limb_fear.wav
# Processed OAF_live_fear.wav
# Processed OAF_loaf_fear.wav
# Processed OAF_long_fear.wav
# Processed OAF_lore_fear.wav
# Processed OAF_lose_fear.wav
# Processed OAF_lot_fear.wav
# Processed OAF_love_fear.wav
# Processed OAF_luck_fear.wav
# Processed OAF_make_fear.wav
# Processed OAF_match_fear.wav
# Processed OAF_merge_fear.wav
# Processed OAF_mess_fear.wav
# Processed OAF_met_fear.wav
# Processed OAF_mill_fear.wav
# Processed OAF_mob_fear.wav
# Processed OAF_mode_fear.wav
# Processed OAF_mood_fear.wav
# Processed OAF_moon_fear.wav
# Processed OAF_mop_fear.wav
# Processed OAF_mouse_fear.wav
# Processed OAF_nag_fear.wav
# Processed OAF_name_fear.wav
# Processed OAF_near_fear.wav
# Processed OAF_neat_fear.wav
# Processed OAF_nice_fear.wav
# Processed OAF_note_fear.wav
# Processed OAF_numb_fear.wav
# Processed OAF_pad_fear.wav
# Processed OAF_page_fear.wav
# Processed OAF_pain_fear.wav
# Processed OAF_pass_fear.wav
# Processed OAF_pearl_fear.wav
# Processed OAF_peg_fear.wav
# Processed OAF_perch_fear.wav
# Processed OAF_phone_fear.wav
# Processed OAF_pick_fear.wav
# Processed OAF_pike_fear.wav
# Processed OAF_pole_fear.wav
# Processed OAF_pool_fear.wav
# Processed OAF_puff_fear.wav
# Processed OAF_rag_fear.wav
# Processed OAF_raid_fear.wav
# Processed OAF_rain_fear.wav
# Processed OAF_raise_fear.wav
# Processed OAF_rat_fear.wav
# Processed OAF_reach_fear.wav
# Processed OAF_read_fear.wav
# Processed OAF_red_fear.wav
# Processed OAF_ring_fear.wav
# Processed OAF_ripe_fear.wav
# Processed OAF_road_fear.wav
# Processed OAF_room_fear.wav
# Processed OAF_rose_fear.wav
# Processed OAF_rot_fear.wav
# Processed OAF_rough_fear.wav
# Processed OAF_rush_fear.wav
# Processed OAF_said_fear.wav
# Processed OAF_sail_fear.wav
# Processed OAF_search_fear.wav
# Processed OAF_seize_fear.wav
# Processed OAF_sell_fear.wav
# Processed OAF_shack_fear.wav
# Processed OAF_shall_fear.wav
# Processed OAF_shawl_fear.wav
# Processed OAF_sheep_fear.wav
# Processed OAF_shirt_fear.wav
# Processed OAF_should_fear.wav
# Processed OAF_shout_fear.wav
# Processed OAF_size_fear.wav
# Processed OAF_soap_fear.wav
# Processed OAF_soup_fear.wav
# Processed OAF_sour_fear.wav
# Processed OAF_south_fear.wav
# Processed OAF_sub_fear.wav
# Processed OAF_such_fear.wav
# Processed OAF_sure_fear.wav
# Processed OAF_take_fear.wav
# Processed OAF_talk_fear.wav
# Processed OAF_tape_fear.wav
# Processed OAF_team_fear.wav
# Processed OAF_tell_fear.wav
# Processed OAF_thin_fear.wav
# Processed OAF_third_fear.wav
# Processed OAF_thought_fear.wav
# Processed OAF_thumb_fear.wav
# Processed OAF_time_fear.wav
# Processed OAF_tip_fear.wav
# Processed OAF_tire_fear.wav
# Processed OAF_ton_fear.wav
# Processed OAF_tool_fear.wav
# Processed OAF_tough_fear.wav
# Processed OAF_turn_fear.wav
# Processed OAF_vine_fear.wav
# Processed OAF_voice_fear.wav
# Processed OAF_void_fear.wav
# Processed OAF_vote_fear.wav
# Processed OAF_wag_fear.wav
# Processed OAF_walk_fear.wav
# Processed OAF_wash_fear.wav
# Processed OAF_week_fear.wav
# Processed OAF_wheat_fear.wav
# Processed OAF_when_fear.wav
# Processed OAF_which_fear.wav
# Processed OAF_whip_fear.wav
# Processed OAF_white_fear.wav
# Processed OAF_wife_fear.wav
# Processed OAF_wire_fear.wav
# Processed OAF_witch_fear.wav
# Processed OAF_yearn_fear.wav
# Processed OAF_yes_fear.wav
# Processed OAF_young_fear.wav
# Processed OAF_youth_fear.wav
# Processed OAF_back_happy.wav
# Processed OAF_bar_happy.wav
# Processed OAF_base_happy.wav
# Processed OAF_bath_happy.wav
# Processed OAF_bean_happy.wav
# Processed OAF_beg_happy.wav
# Processed OAF_bite_happy.wav
# Processed OAF_boat_happy.wav
# Processed OAF_bone_happy.wav
# Processed OAF_book_happy.wav
# Processed OAF_bought_happy.wav
# Processed OAF_burn_happy.wav
# Processed OAF_cab_happy.wav
# Processed OAF_calm_happy.wav
# Processed OAF_came_happy.wav
# Processed OAF_cause_happy.wav
# Processed OAF_chain_happy.wav
# Processed OAF_chair_happy.wav
# Processed OAF_chalk_happy.wav
# Processed OAF_chat_happy.wav
# Processed OAF_check_happy.wav
# Processed OAF_cheek_happy.wav
# Processed OAF_chief_happy.wav
# Processed OAF_choice_happy.wav
# Processed OAF_cool_happy.wav
# Processed OAF_dab_happy.wav
# Processed OAF_date_happy.wav
# Processed OAF_dead_happy.wav
# Processed OAF_death_happy.wav
# Processed OAF_deep_happy.wav
# Processed OAF_dime_happy.wav
# Processed OAF_dip_happy.wav
# Processed OAF_ditch_happy.wav
# Processed OAF_dodge_happy.wav
# Processed OAF_dog_happy.wav
# Processed OAF_doll_happy.wav
# Processed OAF_door_happy.wav
# Processed OAF_fail_happy.wav
# Processed OAF_fall_happy.wav
# Processed OAF_far_happy.wav
# Processed OAF_fat_happy.wav
# Processed OAF_fit_happy.wav
# Processed OAF_five_happy.wav
# Processed OAF_food_happy.wav
# Processed OAF_gap_happy.wav
# Processed OAF_gas_happy.wav
# Processed OAF_gaze_happy.wav
# Processed OAF_germ_happy.wav
# Processed OAF_get_happy.wav
# Processed OAF_gin_happy.wav
# Processed OAF_goal_happy.wav
# Processed OAF_good_happy.wav
# Processed OAF_goose_happy.wav
# Processed OAF_gun_happy.wav
# Processed OAF_half_happy.wav
# Processed OAF_hall_happy.wav
# Processed OAF_hash_happy.wav
# Processed OAF_hate_happy.wav
# Processed OAF_have_happy.wav
# Processed OAF_haze_happy.wav
# Processed OAF_hire_happy.wav
# Processed OAF_hit_happy.wav
# Processed OAF_hole_happy.wav
# Processed OAF_home_happy.wav
# Processed OAF_hurl_happy.wav
# Processed OAF_hush_happy.wav
# Processed OAF_jail_happy.wav
# Processed OAF_jar_happy.wav
# Processed OAF_join_happy.wav
# Processed OAF_judge_happy.wav
# Processed OAF_jug_happy.wav
# Processed OAF_juice_happy.wav
# Processed OAF_keen_happy.wav
# Processed OAF_keep_happy.wav
# Processed OAF_keg_happy.wav
# Processed OAF_kick_happy.wav
# Processed OAF_kill_happy.wav
# Processed OAF_king_happy.wav
# Processed OAF_kite_happy.wav
# Processed OAF_knock_happy.wav
# Processed OAF_late_happy.wav
# Processed OAF_laud_happy.wav
# Processed OAF_lean_happy.wav
# Processed OAF_learn_happy.wav
# Processed OAF_lease_happy.wav
# Processed OAF_lid_happy.wav
# Processed OAF_life_happy.wav
# Processed OAF_limb_happy.wav
# Processed OAF_live_happy.wav
# Processed OAF_loaf_happy.wav
# Processed OAF_long_happy.wav
# Processed OAF_lore_happy.wav
# Processed OAF_lose_happy.wav
# Processed OAF_lot_happy.wav
# Processed OAF_love_happy.wav
# Processed OAF_luck_happy.wav
# Processed OAF_make_happy.wav
# Processed OAF_match_happy.wav
# Processed OAF_merge_happy.wav
# Processed OAF_mess_happy.wav
# Processed OAF_met_happy.wav
# Processed OAF_mill_happy.wav
# Processed OAF_mob_happy.wav
# Processed OAF_mode_happy.wav
# Processed OAF_mood_happy.wav
# Processed OAF_moon_happy.wav
# Processed OAF_mop_happy.wav
# Processed OAF_mouse_happy.wav
# Processed OAF_nag_happy.wav
# Processed OAF_name_happy.wav
# Processed OAF_near_happy.wav
# Processed OAF_neat_happy.wav
# Processed OAF_nice_happy.wav
# Processed OAF_note_happy.wav
# Processed OAF_numb_happy.wav
# Processed OAF_pad_happy.wav
# Processed OAF_page_happy.wav
# Processed OAF_pain_happy.wav
# Processed OAF_pass_happy.wav
# Processed OAF_pearl_happy.wav
# Processed OAF_peg_happy.wav
# Processed OAF_perch_happy.wav
# Processed OAF_phone_happy.wav
# Processed OAF_pick_happy.wav
# Processed OAF_pike_happy.wav
# Processed OAF_pole_happy.wav
# Processed OAF_pool_happy.wav
# Processed OAF_puff_happy.wav
# Processed OAF_rag_happy.wav
# Processed OAF_raid_happy.wav
# Processed OAF_rain_happy.wav
# Processed OAF_raise_happy.wav
# Processed OAF_rat_happy.wav
# Processed OAF_reach_happy.wav
# Processed OAF_read_happy.wav
# Processed OAF_red_happy.wav
# Processed OAF_ring_happy.wav
# Processed OAF_ripe_happy.wav
# Processed OAF_road_happy.wav
# Processed OAF_room_happy.wav
# Processed OAF_rose_happy.wav
# Processed OAF_rot_happy.wav
# Processed OAF_rough_happy.wav
# Processed OAF_rush_happy.wav
# Processed OAF_said_happy.wav
# Processed OAF_sail_happy.wav
# Processed OAF_search_happy.wav
# Processed OAF_seize_happy.wav
# Processed OAF_sell_happy.wav
# Processed OAF_shack_happy.wav
# Processed OAF_shall_happy.wav
# Processed OAF_shawl_happy.wav
# Processed OAF_sheep_happy.wav
# Processed OAF_shirt_happy.wav
# Processed OAF_should_happy.wav
# Processed OAF_shout_happy.wav
# Processed OAF_size_happy.wav
# Processed OAF_soap_happy.wav
# Processed OAF_soup_happy.wav
# Processed OAF_sour_happy.wav
# Processed OAF_south_happy.wav
# Processed OAF_sub_happy.wav
# Processed OAF_such_happy.wav
# Processed OAF_sure_happy.wav
# Processed OAF_take_happy.wav
# Processed OAF_talk_happy.wav
# Processed OAF_tape_happy.wav
# Processed OAF_team_happy.wav
# Processed OAF_tell_happy.wav
# Processed OAF_thin_happy.wav
# Processed OAF_third_happy.wav
# Processed OAF_thought_happy.wav
# Processed OAF_thumb_happy.wav
# Processed OAF_time_happy.wav
# Processed OAF_tip_happy.wav
# Processed OAF_tire_happy.wav
# Processed OAF_ton_happy.wav
# Processed OAF_tool_happy.wav
# Processed OAF_tough_happy.wav
# Processed OAF_turn_happy.wav
# Processed OAF_vine_happy.wav
# Processed OAF_voice_happy.wav
# Processed OAF_void_happy.wav
# Processed OAF_vote_happy.wav
# Processed OAF_wag_happy.wav
# Processed OAF_walk_happy.wav
# Processed OAF_wash_happy.wav
# Processed OAF_week_happy.wav
# Processed OAF_wheat_happy.wav
# Processed OAF_when_happy.wav
# Processed OAF_which_happy.wav
# Processed OAF_whip_happy.wav
# Processed OAF_white_happy.wav
# Processed OAF_wife_happy.wav
# Processed OAF_wire_happy.wav
# Processed OAF_witch_happy.wav
# Processed OAF_yearn_happy.wav
# Processed OAF_yes_happy.wav
# Processed OAF_young_happy.wav
# Processed OAF_youth_happy.wav
# Processed OAF_back_neutral.wav
# Processed OAF_bar_neutral.wav
# Processed OAF_base_neutral.wav
# Processed OAF_bath_neutral.wav
# Processed OAF_bean_neutral.wav
# Processed OAF_beg_neutral.wav
# Processed OAF_boat_neutral.wav
# Processed OAF_bone_neutral.wav
# Processed OAF_book_neutral.wav
# Processed OAF_bought_neutral.wav
# Processed OAF_burn_neutral.wav
# Processed OAF_cab_neutral.wav
# Processed OAF_calm_neutral.wav
# Processed OAF_came_neutral.wav
# Processed OAF_cause_neutral.wav
# Processed OAF_chain_neutral.wav
# Processed OAF_chair_neutral.wav
# Processed OAF_chalk_neutral.wav
# Processed OAF_chat_neutral.wav
# Processed OAF_check_neutral.wav
# Processed OAF_cheek_neutral.wav
# Processed OAF_chief_neutral.wav
# Processed OAF_choice_neutral.wav
# Processed OAF_cool_neutral.wav
# Processed OAF_dab_neutral.wav
# Processed OAF_date_neutral.wav
# Processed OAF_dead_neutral.wav
# Processed OAF_death_neutral.wav
# Processed OAF_deep_neutral.wav
# Processed OAF_dime_neutral.wav
# Processed OAF_dip_neutral.wav
# Processed OAF_ditch_neutral.wav
# Processed OAF_dodge_neutral.wav
# Processed OAF_dog_neutral.wav
# Processed OAF_doll_neutral.wav
# Processed OAF_door_neutral.wav
# Processed OAF_fail_neutral.wav
# Processed OAF_fall_neutral.wav
# Processed OAF_far_neutral.wav
# Processed OAF_fat_neutral.wav
# Processed OAF_fit_neutral.wav
# Processed OAF_five_neutral.wav
# Processed OAF_food_neutral.wav
# Processed OAF_gap_neutral.wav
# Processed OAF_gas_neutral.wav
# Processed OAF_gaze_neutral.wav
# Processed OAF_germ_neutral.wav
# Processed OAF_get_neutral.wav
# Processed OAF_gin_neutral.wav
# Processed OAF_goal_neutral.wav
# Processed OAF_good_neutral.wav
# Processed OAF_goose_neutral.wav
# Processed OAF_gun_neutral.wav
# Processed OAF_half_neutral.wav
# Processed OAF_hall_neutral.wav
# Processed OAF_hash_neutral.wav
# Processed OAF_hate_neutral.wav
# Processed OAF_have_neutral.wav
# Processed OAF_haze_neutral.wav
# Processed OAF_hire_neutral.wav
# Processed OAF_hit_neutral.wav
# Processed OAF_hole_neutral.wav
# Processed OAF_home_neutral.wav
# Processed OAF_hurl_neutral.wav
# Processed OAF_hush_neutral.wav
# Processed OAF_jail_neutral.wav
# Processed OAF_jar_neutral.wav
# Processed OAF_join_neutral.wav
# Processed OAF_judge_neutral.wav
# Processed OAF_jug_neutral.wav
# Processed OAF_juice_neutral.wav
# Processed OAF_keen_neutral.wav
# Processed OAF_keep_neutral.wav
# Processed OAF_keg_neutral.wav
# Processed OAF_kick_neutral.wav
# Processed OAF_kill_neutral.wav
# Processed OAF_king_neutral.wav
# Processed OAF_kite_neutral.wav
# Processed OAF_knock_neutral.wav
# Processed OAF_late_neutral.wav
# Processed OAF_laud_neutral.wav
# Processed OAF_lean_neutral.wav
# Processed OAF_learn_neutral.wav
# Processed OAF_lease_neutral.wav
# Processed OAF_lid_neutral.wav
# Processed OAF_life_neutral.wav
# Processed OAF_limb_neutral.wav
# Processed OAF_live_neutral.wav
# Processed OAF_loaf_neutral.wav
# Processed OAF_long_neutral.wav
# Processed OAF_lore_neutral.wav
# Processed OAF_lose_neutral.wav
# Processed OAF_lot_neutral.wav
# Processed OAF_love_neutral.wav
# Processed OAF_luck_neutral.wav
# Processed OAF_make_neutral.wav
# Processed OAF_match_neutral.wav
# Processed OAF_merge_neutral.wav
# Processed OAF_mess_neutral.wav
# Processed OAF_met_neutral.wav
# Processed OAF_mill_neutral.wav
# Processed OAF_mob_neutral.wav
# Processed OAF_mode_neutral.wav
# Processed OAF_mood_neutral.wav
# Processed OAF_moon_neutral.wav
# Processed OAF_mop_neutral.wav
# Processed OAF_mouse_neutral.wav
# Processed OAF_nag_neutral.wav
# Processed OAF_name_neutral.wav
# Processed OAF_near_neutral.wav
# Processed OAF_neat_neutral.wav
# Processed OAF_nice_neutral.wav
# Processed OAF_note_neutral.wav
# Processed OAF_numb_neutral.wav
# Processed OAF_pad_neutral.wav
# Processed OAF_page_neutral.wav
# Processed OAF_pain_neutral.wav
# Processed OAF_pass_neutral.wav
# Processed OAF_pearl_neutral.wav
# Processed OAF_peg_neutral.wav
# Processed OAF_perch_neutral.wav
# Processed OAF_phone_neutral.wav
# Processed OAF_pick_neutral.wav
# Processed OAF_pike_neutral.wav
# Processed OAF_pole_neutral.wav
# Processed OAF_pool_neutral.wav
# Processed OAF_puff_neutral.wav
# Processed OAF_rag_neutral.wav
# Processed OAF_raid_neutral.wav
# Processed OAF_rain_neutral.wav
# Processed OAF_raise_neutral.wav
# Processed OAF_rat_neutral.wav
# Processed OAF_reach_neutral.wav
# Processed OAF_read_neutral.wav
# Processed OAF_red_neutral.wav
# Processed OAF_ring_neutral.wav
# Processed OAF_ripe_neutral.wav
# Processed OAF_road_neutral.wav
# Processed OAF_room_neutral.wav
# Processed OAF_rose_neutral.wav
# Processed OAF_rot_neutral.wav
# Processed OAF_rough_neutral.wav
# Processed OAF_rush_neutral.wav
# Processed OAF_said_neutral.wav
# Processed OAF_sail_neutral.wav
# Processed OAF_search_neutral.wav
# Processed OAF_seize_neutral.wav
# Processed OAF_sell_neutral.wav
# Processed OAF_shack_neutral.wav
# Processed OAF_shall_neutral.wav
# Processed OAF_shawl_neutral.wav
# Processed OAF_sheep_neutral.wav
# Processed OAF_shirt_neutral.wav
# Processed OAF_should_neutral.wav
# Processed OAF_shout_neutral.wav
# Processed OAF_size_neutral.wav
# Processed OAF_soap_neutral.wav
# Processed OAF_soup_neutral.wav
# Processed OAF_sour_neutral.wav
# Processed OAF_south_neutral.wav
# Processed OAF_sub_neutral.wav
# Processed OAF_such_neutral.wav
# Processed OAF_sure_neutral.wav
# Processed OAF_take_neutral.wav
# Processed OAF_talk_neutral.wav
# Processed OAF_tape_neutral.wav
# Processed OAF_team_neutral.wav
# Processed OAF_tell_neutral.wav
# Processed OAF_thin_neutral.wav
# Processed OAF_third_neutral.wav
# Processed OAF_thought_neutral.wav
# Processed OAF_thumb_neutral.wav
# Processed OAF_time_neutral.wav
# Processed OAF_tip_neutral.wav
# Processed OAF_tire_neutral.wav
# Processed OAF_ton_neutral.wav
# Processed OAF_tool_neutral.wav
# Processed OAF_tough_neutral.wav
# Processed OAF_turn_neutral.wav
# Processed OAF_vine_neutral.wav
# Processed OAF_voice_neutral.wav
# Processed OAF_void_neutral.wav
# Processed OAF_vote_neutral.wav
# Processed OAF_wag_neutral.wav
# Processed OAF_walk_neutral.wav
# Processed OAF_wash_neutral.wav
# Processed OAF_week_neutral.wav
# Processed OAF_wheat_neutral.wav
# Processed OAF_when_neutral.wav
# Processed OAF_which_neutral.wav
# Processed OAF_whip_neutral.wav
# Processed OAF_white_neutral.wav
# Processed OAF_wife_neutral.wav
# Processed OAF_wire_neutral.wav
# Processed OAF_witch_neutral.wav
# Processed OAF_yearn_neutral.wav
# Processed OAF_yes_neutral.wav
# Processed OAF_young_neutral.wav
# Processed OAF_youth_neutral.wav
# Processed OA_bite_neutral.wav
# Processed OAF_back_ps.wav
# Processed OAF_bar_ps.wav
# Processed OAF_base_ps.wav
# Processed OAF_bath_ps.wav
# Processed OAF_bean_ps.wav
# Processed OAF_beg_ps.wav
# Processed OAF_bite_ps.wav
# Processed OAF_boat_ps.wav
# Processed OAF_bone_ps.wav
# Processed OAF_book_ps.wav
# Processed OAF_bought_ps.wav
# Processed OAF_burn_ps.wav
# Processed OAF_cab_ps.wav
# Processed OAF_calm_ps.wav
# Processed OAF_came_ps.wav
# Processed OAF_cause_ps.wav
# Processed OAF_chain_ps.wav
# Processed OAF_chair_ps.wav
# Processed OAF_chalk_ps.wav
# Processed OAF_chat_ps.wav
# Processed OAF_check_ps.wav
# Processed OAF_cheek_ps.wav
# Processed OAF_chief_ps.wav
# Processed OAF_choice_ps.wav
# Processed OAF_cool_ps.wav
# Processed OAF_dab_ps.wav
# Processed OAF_date_ps.wav
# Processed OAF_dead_ps.wav
# Processed OAF_death_ps.wav
# Processed OAF_deep_ps.wav
# Processed OAF_dime_ps.wav
# Processed OAF_dip_ps.wav
# Processed OAF_ditch_ps.wav
# Processed OAF_dodge_ps.wav
# Processed OAF_dog_ps.wav
# Processed OAF_doll_ps.wav
# Processed OAF_door_ps.wav
# Processed OAF_fail_ps.wav
# Processed OAF_fall_ps.wav
# Processed OAF_far_ps.wav
# Processed OAF_fat_ps.wav
# Processed OAF_fit_ps.wav
# Processed OAF_five_ps.wav
# Processed OAF_food_ps.wav
# Processed OAF_gap_ps.wav
# Processed OAF_gas_ps.wav
# Processed OAF_gaze_ps.wav
# Processed OAF_germ_ps.wav
# Processed OAF_get_ps.wav
# Processed OAF_gin_ps.wav
# Processed OAF_goal_ps.wav
# Processed OAF_good_ps.wav
# Processed OAF_goose_ps.wav
# Processed OAF_gun_ps.wav
# Processed OAF_half_ps.wav
# Processed OAF_hall_ps.wav
# Processed OAF_hash_ps.wav
# Processed OAF_hate_ps.wav
# Processed OAF_have_ps.wav
# Processed OAF_haze_ps.wav
# Processed OAF_hire_ps.wav
# Processed OAF_hit_ps.wav
# Processed OAF_hole_ps.wav
# Processed OAF_home_ps.wav
# Processed OAF_hurl_ps.wav
# Processed OAF_hush_ps.wav
# Processed OAF_jail_ps.wav
# Processed OAF_jar_ps.wav
# Processed OAF_join_ps.wav
# Processed OAF_judge_ps.wav
# Processed OAF_jug_ps.wav
# Processed OAF_juice_ps.wav
# Processed OAF_keen_ps.wav
# Processed OAF_keep_ps.wav
# Processed OAF_keg_ps.wav
# Processed OAF_kick_ps.wav
# Processed OAF_kill_ps.wav
# Processed OAF_king_ps.wav
# Processed OAF_kite_ps.wav
# Processed OAF_knock_ps.wav
# Processed OAF_late_ps.wav
# Processed OAF_laud_ps.wav
# Processed OAF_lean_ps.wav
# Processed OAF_learn_ps.wav
# Processed OAF_lease_ps.wav
# Processed OAF_lid_ps.wav
# Processed OAF_life_ps.wav
# Processed OAF_limb_ps.wav
# Processed OAF_live_ps.wav
# Processed OAF_loaf_ps.wav
# Processed OAF_long_ps.wav
# Processed OAF_lore_ps.wav
# Processed OAF_lose_ps.wav
# Processed OAF_lot_ps.wav
# Processed OAF_love_ps.wav
# Processed OAF_luck_ps.wav
# Processed OAF_make_ps.wav
# Processed OAF_match_ps.wav
# Processed OAF_merge_ps.wav
# Processed OAF_mess_ps.wav
# Processed OAF_met_ps.wav
# Processed OAF_mill_ps.wav
# Processed OAF_mob_ps.wav
# Processed OAF_mode_ps.wav
# Processed OAF_mood_ps.wav
# Processed OAF_moon_ps.wav
# Processed OAF_mop_ps.wav
# Processed OAF_mouse_ps.wav
# Processed OAF_nag_ps.wav
# Processed OAF_name_ps.wav
# Processed OAF_near_ps.wav
# Processed OAF_neat_ps.wav
# Processed OAF_nice_ps.wav
# Processed OAF_note_ps.wav
# Processed OAF_numb_ps.wav
# Processed OAF_pad_ps.wav
# Processed OAF_page_ps.wav
# Processed OAF_pain_ps.wav
# Processed OAF_pass_ps.wav
# Processed OAF_pearl_ps.wav
# Processed OAF_peg_ps.wav
# Processed OAF_perch_ps.wav
# Processed OAF_phone_ps.wav
# Processed OAF_pick_ps.wav
# Processed OAF_pike_ps.wav
# Processed OAF_pole_ps.wav
# Processed OAF_pool_ps.wav
# Processed OAF_puff_ps.wav
# Processed OAF_rag_ps.wav
# Processed OAF_raid_ps.wav
# Processed OAF_rain_ps.wav
# Processed OAF_raise_ps.wav
# Processed OAF_rat_ps.wav
# Processed OAF_reach_ps.wav
# Processed OAF_read_ps.wav
# Processed OAF_red_ps.wav
# Processed OAF_ring_ps.wav
# Processed OAF_ripe_ps.wav
# Processed OAF_road_ps.wav
# Processed OAF_room_ps.wav
# Processed OAF_rose_ps.wav
# Processed OAF_rot_ps.wav
# Processed OAF_rough_ps.wav
# Processed OAF_rush_ps.wav
# Processed OAF_said_ps.wav
# Processed OAF_sail_ps.wav
# Processed OAF_search_ps.wav
# Processed OAF_seize_ps.wav
# Processed OAF_sell_ps.wav
# Processed OAF_shack_ps.wav
# Processed OAF_shall_ps.wav
# Processed OAF_shawl_ps.wav
# Processed OAF_sheep_ps.wav
# Processed OAF_shirt_ps.wav
# Processed OAF_should_ps.wav
# Processed OAF_shout_ps.wav
# Processed OAF_size_ps.wav
# Processed OAF_soap_ps.wav
# Processed OAF_soup_ps.wav
# Processed OAF_sour_ps.wav
# Processed OAF_south_ps.wav
# Processed OAF_sub_ps.wav
# Processed OAF_such_ps.wav
# Processed OAF_sure_ps.wav
# Processed OAF_take_ps.wav
# Processed OAF_talk_ps.wav
# Processed OAF_tape_ps.wav
# Processed OAF_team_ps.wav
# Processed OAF_tell_ps.wav
# Processed OAF_thin_ps.wav
# Processed OAF_third_ps.wav
# Processed OAF_thought_ps.wav
# Processed OAF_thumb_ps.wav
# Processed OAF_time_ps.wav
# Processed OAF_tip_ps.wav
# Processed OAF_tire_ps.wav
# Processed OAF_ton_ps.wav
# Processed OAF_tool_ps.wav
# Processed OAF_tough_ps.wav
# Processed OAF_turn_ps.wav
# Processed OAF_vine_ps.wav
# Processed OAF_voice_ps.wav
# Processed OAF_void_ps.wav
# Processed OAF_vote_ps.wav
# Processed OAF_wag_ps.wav
# Processed OAF_walk_ps.wav
# Processed OAF_wash_ps.wav
# Processed OAF_week_ps.wav
# Processed OAF_wheat_ps.wav
# Processed OAF_when_ps.wav
# Processed OAF_which_ps.wav
# Processed OAF_whip_ps.wav
# Processed OAF_white_ps.wav
# Processed OAF_wife_ps.wav
# Processed OAF_wire_ps.wav
# Processed OAF_witch_ps.wav
# Processed OAF_yearn_ps.wav
# Processed OAF_yes_ps.wav
# Processed OAF_young_ps.wav
# Processed OAF_youth_ps.wav
# Processed OAF_back_sad.wav
# Processed OAF_bar_sad.wav
# Processed OAF_base_sad.wav
# Processed OAF_bath_sad.wav
# Processed OAF_bean_sad.wav
# Processed OAF_beg_sad.wav
# Processed OAF_bite_sad.wav
# Processed OAF_boat_sad.wav
# Processed OAF_bone_sad.wav
# Processed OAF_book_sad.wav
# Processed OAF_bought_sad.wav
# Processed OAF_burn_sad.wav
# Processed OAF_cab_sad.wav
# Processed OAF_calm_sad.wav
# Processed OAF_came_sad.wav
# Processed OAF_cause_sad.wav
# Processed OAF_chain_sad.wav
# Processed OAF_chair_sad.wav
# Processed OAF_chalk_sad.wav
# Processed OAF_chat_sad.wav
# Processed OAF_check_sad.wav
# Processed OAF_cheek_sad.wav
# Processed OAF_chief_sad.wav
# Processed OAF_choice_sad.wav
# Processed OAF_cool_sad.wav
# Processed OAF_dab_sad.wav
# Processed OAF_date_sad.wav
# Processed OAF_dead_sad.wav
# Processed OAF_death_sad.wav
# Processed OAF_deep_sad.wav
# Processed OAF_dime_sad.wav
# Processed OAF_dip_sad.wav
# Processed OAF_ditch_sad.wav
# Processed OAF_dodge_sad.wav
# Processed OAF_dog_sad.wav
# Processed OAF_doll_sad.wav
# Processed OAF_door_sad.wav
# Processed OAF_fail_sad.wav
# Processed OAF_fall_sad.wav
# Processed OAF_far_sad.wav
# Processed OAF_fat_sad.wav
# Processed OAF_fit_sad.wav
# Processed OAF_five_sad.wav
# Processed OAF_food_sad.wav
# Processed OAF_gap_sad.wav
# Processed OAF_gas_sad.wav
# Processed OAF_gaze_sad.wav
# Processed OAF_germ_sad.wav
# Processed OAF_get_sad.wav
# Processed OAF_gin_sad.wav
# Processed OAF_goal_sad.wav
# Processed OAF_good_sad.wav
# Processed OAF_goose_sad.wav
# Processed OAF_gun_sad.wav
# Processed OAF_half_sad.wav
# Processed OAF_hall_sad.wav
# Processed OAF_hash_sad.wav
# Processed OAF_hate_sad.wav
# Processed OAF_have_sad.wav
# Processed OAF_haze_sad.wav
# Processed OAF_hire_sad.wav
# Processed OAF_hit_sad.wav
# Processed OAF_hole_sad.wav
# Processed OAF_home_sad.wav
# Processed OAF_hurl_sad.wav
# Processed OAF_hush_sad.wav
# Processed OAF_jail_sad.wav
# Processed OAF_jar_sad.wav
# Processed OAF_join_sad.wav
# Processed OAF_judge_sad.wav
# Processed OAF_jug_sad.wav
# Processed OAF_juice_sad.wav
# Processed OAF_keen_sad.wav
# Processed OAF_keep_sad.wav
# Processed OAF_keg_sad.wav
# Processed OAF_kick_sad.wav
# Processed OAF_kill_sad.wav
# Processed OAF_king_sad.wav
# Processed OAF_kite_sad.wav
# Processed OAF_knock_sad.wav
# Processed OAF_late_sad.wav
# Processed OAF_laud_sad.wav
# Processed OAF_lean_sad.wav
# Processed OAF_learn_sad.wav
# Processed OAF_lease_sad.wav
# Processed OAF_lid_sad.wav
# Processed OAF_life_sad.wav
# Processed OAF_limb_sad.wav
# Processed OAF_live_sad.wav
# Processed OAF_loaf_sad.wav
# Processed OAF_long_sad.wav
# Processed OAF_lore_sad.wav
# Processed OAF_lose_sad.wav
# Processed OAF_lot_sad.wav
# Processed OAF_love_sad.wav
# Processed OAF_luck_sad.wav
# Processed OAF_make_sad.wav
# Processed OAF_match_sad.wav
# Processed OAF_merge_sad.wav
# Processed OAF_mess_sad.wav
# Processed OAF_met_sad.wav
# Processed OAF_mill_sad.wav
# Processed OAF_mob_sad.wav
# Processed OAF_mode_sad.wav
# Processed OAF_mood_sad.wav
# Processed OAF_moon_sad.wav
# Processed OAF_mop_sad.wav
# Processed OAF_mouse_sad.wav
# Processed OAF_nag_sad.wav
# Processed OAF_name_sad.wav
# Processed OAF_near_sad.wav
# Processed OAF_neat_sad.wav
# Processed OAF_nice_sad.wav
# Processed OAF_note_sad.wav
# Processed OAF_numb_sad.wav
# Processed OAF_pad_sad.wav
# Processed OAF_page_sad.wav
# Processed OAF_pain_sad.wav
# Processed OAF_pass_sad.wav
# Processed OAF_pearl_sad.wav
# Processed OAF_peg_sad.wav
# Processed OAF_perch_sad.wav
# Processed OAF_phone_sad.wav
# Processed OAF_pick_sad.wav
# Processed OAF_pike_sad.wav
# Processed OAF_pole_sad.wav
# Processed OAF_pool_sad.wav
# Processed OAF_puff_sad.wav
# Processed OAF_rag_sad.wav
# Processed OAF_raid_sad.wav
# Processed OAF_rain_sad.wav
# Processed OAF_raise_sad.wav
# Processed OAF_rat_sad.wav
# Processed OAF_reach_sad.wav
# Processed OAF_read_sad.wav
# Processed OAF_red_sad.wav
# Processed OAF_ring_sad.wav
# Processed OAF_ripe_sad.wav
# Processed OAF_road_sad.wav
# Processed OAF_room_sad.wav
# Processed OAF_rose_sad.wav
# Processed OAF_rot_sad.wav
# Processed OAF_rough_sad.wav
# Processed OAF_rush_sad.wav
# Processed OAF_said_sad.wav
# Processed OAF_sail_sad.wav
# Processed OAF_search_sad.wav
# Processed OAF_seize_sad.wav
# Processed OAF_sell_sad.wav
# Processed OAF_shack_sad.wav
# Processed OAF_shall_sad.wav
# Processed OAF_shawl_sad.wav
# Processed OAF_sheep_sad.wav
# Processed OAF_shirt_sad.wav
# Processed OAF_should_sad.wav
# Processed OAF_shout_sad.wav
# Processed OAF_size_sad.wav
# Processed OAF_soap_sad.wav
# Processed OAF_soup_sad.wav
# Processed OAF_sour_sad.wav
# Processed OAF_south_sad.wav
# Processed OAF_sub_sad.wav
# Processed OAF_such_sad.wav
# Processed OAF_sure_sad.wav
# Processed OAF_take_sad.wav
# Processed OAF_talk_sad.wav
# Processed OAF_tape_sad.wav
# Processed OAF_team_sad.wav
# Processed OAF_tell_sad.wav
# Processed OAF_thin_sad.wav
# Processed OAF_third_sad.wav
# Processed OAF_thought_sad.wav
# Processed OAF_thumb_sad.wav
# Processed OAF_time_sad.wav
# Processed OAF_tip_sad.wav
# Processed OAF_tire_sad.wav
# Processed OAF_ton_sad.wav
# Processed OAF_tool_sad.wav
# Processed OAF_tough_sad.wav
# Processed OAF_turn_sad.wav
# Processed OAF_vine_sad.wav
# Processed OAF_voice_sad.wav
# Processed OAF_void_sad.wav
# Processed OAF_vote_sad.wav
# Processed OAF_wag_sad.wav
# Processed OAF_walk_sad.wav
# Processed OAF_wash_sad.wav
# Processed OAF_week_sad.wav
# Processed OAF_wheat_sad.wav
# Processed OAF_when_sad.wav
# Processed OAF_which_sad.wav
# Processed OAF_whip_sad.wav
# Processed OAF_white_sad.wav
# Processed OAF_wife_sad.wav
# Processed OAF_wire_sad.wav
# Processed OAF_witch_sad.wav
# Processed OAF_yearn_sad.wav
# Processed OAF_yes_sad.wav
# Processed OAF_young_sad.wav
# Processed OAF_youth_sad.wav
# Processed YAF_back_angry.wav
# Processed YAF_bar_angry.wav
# Processed YAF_base_angry.wav
# Processed YAF_bath_angry.wav
# Processed YAF_bean_angry.wav
# Processed YAF_beg_angry.wav
# Processed YAF_bite_angry.wav
# Processed YAF_boat_angry.wav
# Processed YAF_bone_angry.wav
# Processed YAF_book_angry.wav
# Processed YAF_bought_angry.wav
# Processed YAF_burn_angry.wav
# Processed YAF_cab_angry.wav
# Processed YAF_calm_angry.wav
# Processed YAF_came_angry.wav
# Processed YAF_cause_angry.wav
# Processed YAF_chain_angry.wav
# Processed YAF_chair_angry.wav
# Processed YAF_chalk_angry.wav
# Processed YAF_chat_angry.wav
# Processed YAF_check_angry.wav
# Processed YAF_cheek_angry.wav
# Processed YAF_chief_angry.wav
# Processed YAF_choice_angry.wav
# Processed YAF_cool_angry.wav
# Processed YAF_dab_angry.wav
# Processed YAF_date_angry.wav
# Processed YAF_dead_angry.wav
# Processed YAF_death_angry.wav
# Processed YAF_deep_angry.wav
# Processed YAF_dime_angry.wav
# Processed YAF_dip_angry.wav
# Processed YAF_ditch_angry.wav
# Processed YAF_dodge_angry.wav
# Processed YAF_dog_angry.wav
# Processed YAF_doll_angry.wav
# Processed YAF_door_angry.wav
# Processed YAF_fail_angry.wav
# Processed YAF_fall_angry.wav
# Processed YAF_far_angry.wav
# Processed YAF_fat_angry.wav
# Processed YAF_fit_angry.wav
# Processed YAF_five_angry.wav
# Processed YAF_food_angry.wav
# Processed YAF_gap_angry.wav
# Processed YAF_gas_angry.wav
# Processed YAF_gaze_angry.wav
# Processed YAF_germ_angry.wav
# Processed YAF_get_angry.wav
# Processed YAF_gin_angry.wav
# Processed YAF_goal_angry.wav
# Processed YAF_good_angry.wav
# Processed YAF_goose_angry.wav
# Processed YAF_gun_angry.wav
# Processed YAF_half_angry.wav
# Processed YAF_hall_angry.wav
# Processed YAF_hash_angry.wav
# Processed YAF_hate_angry.wav
# Processed YAF_have_angry.wav
# Processed YAF_haze_angry.wav
# Processed YAF_hire_angry.wav
# Processed YAF_hit_angry.wav
# Processed YAF_hole_angry.wav
# Processed YAF_home_angry.wav
# Processed YAF_hurl_angry.wav
# Processed YAF_hush_angry.wav
# Processed YAF_jail_angry.wav
# Processed YAF_jar_angry.wav
# Processed YAF_join_angry.wav
# Processed YAF_judge_angry.wav
# Processed YAF_jug_angry.wav
# Processed YAF_juice_angry.wav
# Processed YAF_keen_angry.wav
# Processed YAF_keep_angry.wav
# Processed YAF_keg_angry.wav
# Processed YAF_kick_angry.wav
# Processed YAF_kill_angry.wav
# Processed YAF_king_angry.wav
# Processed YAF_kite_angry.wav
# Processed YAF_knock_angry.wav
# Processed YAF_late_angry.wav
# Processed YAF_laud_angry.wav
# Processed YAF_lean_angry.wav
# Processed YAF_learn_angry.wav
# Processed YAF_lease_angry.wav
# Processed YAF_lid_angry.wav
# Processed YAF_life_angry.wav
# Processed YAF_limb_angry.wav
# Processed YAF_live_angry.wav
# Processed YAF_loaf_angry.wav
# Processed YAF_long_angry.wav
# Processed YAF_lore_angry.wav
# Processed YAF_lose_angry.wav
# Processed YAF_lot_angry.wav
# Processed YAF_love_angry.wav
# Processed YAF_luck_angry.wav
# Processed YAF_make_angry.wav
# Processed YAF_match_angry.wav
# Processed YAF_merge_angry.wav
# Processed YAF_mess_angry.wav
# Processed YAF_met_angry.wav
# Processed YAF_mill_angry.wav
# Processed YAF_mob_angry.wav
# Processed YAF_mode_angry.wav
# Processed YAF_mood_angry.wav
# Processed YAF_moon_angry.wav
# Processed YAF_mop_angry.wav
# Processed YAF_mouse_angry.wav
# Processed YAF_nag_angry.wav
# Processed YAF_name_angry.wav
# Processed YAF_near_angry.wav
# Processed YAF_neat_angry.wav
# Processed YAF_nice_angry.wav
# Processed YAF_note_angry.wav
# Processed YAF_numb_angry.wav
# Processed YAF_pad_angry.wav
# Processed YAF_page_angry.wav
# Processed YAF_pain_angry.wav
# Processed YAF_pass_angry.wav
# Processed YAF_pearl_angry.wav
# Processed YAF_peg_angry.wav
# Processed YAF_perch_angry.wav
# Processed YAF_phone_angry.wav
# Processed YAF_pick_angry.wav
# Processed YAF_pike_angry.wav
# Processed YAF_pole_angry.wav
# Processed YAF_pool_angry.wav
# Processed YAF_puff_angry.wav
# Processed YAF_rag_angry.wav
# Processed YAF_raid_angry.wav
# Processed YAF_rain_angry.wav
# Processed YAF_raise_angry.wav
# Processed YAF_rat_angry.wav
# Processed YAF_reach_angry.wav
# Processed YAF_read_angry.wav
# Processed YAF_red_angry.wav
# Processed YAF_ring_angry.wav
# Processed YAF_ripe_angry.wav
# Processed YAF_road_angry.wav
# Processed YAF_room_angry.wav
# Processed YAF_rose_angry.wav
# Processed YAF_rot_angry.wav
# Processed YAF_rough_angry.wav
# Processed YAF_rush_angry.wav
# Processed YAF_said_angry.wav
# Processed YAF_sail_angry.wav
# Processed YAF_search_angry.wav
# Processed YAF_seize_angry.wav
# Processed YAF_sell_angry.wav
# Processed YAF_shack_angry.wav
# Processed YAF_shall_angry.wav
# Processed YAF_shawl_angry.wav
# Processed YAF_sheep_angry.wav
# Processed YAF_shirt_angry.wav
# Processed YAF_should_angry.wav
# Processed YAF_shout_angry.wav
# Processed YAF_size_angry.wav
# Processed YAF_soap_angry.wav
# Processed YAF_soup_angry.wav
# Processed YAF_sour_angry.wav
# Processed YAF_south_angry.wav
# Processed YAF_sub_angry.wav
# Processed YAF_such_angry.wav
# Processed YAF_sure_angry.wav
# Processed YAF_take_angry.wav
# Processed YAF_talk_angry.wav
# Processed YAF_tape_angry.wav
# Processed YAF_team_angry.wav
# Processed YAF_tell_angry.wav
# Processed YAF_thin_angry.wav
# Processed YAF_third_angry.wav
# Processed YAF_thought_angry.wav
# Processed YAF_thumb_angry.wav
# Processed YAF_time_angry.wav
# Processed YAF_tip_angry.wav
# Processed YAF_tire_angry.wav
# Processed YAF_ton_angry.wav
# Processed YAF_tool_angry.wav
# Processed YAF_tough_angry.wav
# Processed YAF_turn_angry.wav
# Processed YAF_vine_angry.wav
# Processed YAF_voice_angry.wav
# Processed YAF_void_angry.wav
# Processed YAF_vote_angry.wav
# Processed YAF_wag_angry.wav
# Processed YAF_walk_angry.wav
# Processed YAF_wash_angry.wav
# Processed YAF_week_angry.wav
# Processed YAF_wheat_angry.wav
# Processed YAF_when_angry.wav
# Processed YAF_which_angry.wav
# Processed YAF_whip_angry.wav
# Processed YAF_white_angry.wav
# Processed YAF_wife_angry.wav
# Processed YAF_wire_angry.wav
# Processed YAF_witch_angry.wav
# Processed YAF_yearn_angry.wav
# Processed YAF_yes_angry.wav
# Processed YAF_young_angry.wav
# Processed YAF_youth_angry.wav
# Processed YAF_back_disgust.wav
# Processed YAF_bar_disgust.wav
# Processed YAF_base_disgust.wav
# Processed YAF_bath_disgust.wav
# Processed YAF_bean_disgust.wav
# Processed YAF_beg_disgust.wav
# Processed YAF_bite_disgust.wav
# Processed YAF_boat_disgust.wav
# Processed YAF_bone_disgust.wav
# Processed YAF_book_disgust.wav
# Processed YAF_bought_disgust.wav
# Processed YAF_burn_disgust.wav
# Processed YAF_cab_disgust.wav
# Processed YAF_calm_disgust.wav
# Processed YAF_came_disgust.wav
# Processed YAF_cause_disgust.wav
# Processed YAF_chain_disgust.wav
# Processed YAF_chair_disgust.wav
# Processed YAF_chalk_disgust.wav
# Processed YAF_chat_disgust.wav
# Processed YAF_check_disgust.wav
# Processed YAF_cheek_disgust.wav
# Processed YAF_chief_disgust.wav
# Processed YAF_choice_disgust.wav
# Processed YAF_cool_disgust.wav
# Processed YAF_dab_disgust.wav
# Processed YAF_date_disgust.wav
# Processed YAF_dead_disgust.wav
# Processed YAF_death_disgust.wav
# Processed YAF_deep_disgust.wav
# Processed YAF_dime_disgust.wav
# Processed YAF_dip_disgust.wav
# Processed YAF_ditch_disgust.wav
# Processed YAF_dodge_disgust.wav
# Processed YAF_dog_disgust.wav
# Processed YAF_doll_disgust.wav
# Processed YAF_door_disgust.wav
# Processed YAF_fail_disgust.wav
# Processed YAF_fall_disgust.wav
# Processed YAF_far_disgust.wav
# Processed YAF_fat_disgust.wav
# Processed YAF_fit_disgust.wav
# Processed YAF_five_disgust.wav
# Processed YAF_food_disgust.wav
# Processed YAF_gap_disgust.wav
# Processed YAF_gas_disgust.wav
# Processed YAF_gaze_disgust.wav
# Processed YAF_germ_disgust.wav
# Processed YAF_get_disgust.wav
# Processed YAF_gin_disgust.wav
# Processed YAF_goal_disgust.wav
# Processed YAF_good_disgust.wav
# Processed YAF_goose_disgust.wav
# Processed YAF_gun_disgust.wav
# Processed YAF_half_disgust.wav
# Processed YAF_hall_disgust.wav
# Processed YAF_hash_disgust.wav
# Processed YAF_hate_disgust.wav
# Processed YAF_have_disgust.wav
# ...
# Processed YAF_lease_neutral.wav
# Processed YAF_lid_neutral.wav
# Processed YAF_life_neutral.wav
# Processed YAF_limb_neutral.wav
# Processed YAF_live_neutral.wav
# Processed YAF_loaf_neutral.wav
# Processed YAF_long_neutral.wav
# Processed YAF_lore_neutral.wav
# Processed YAF_lose_neutral.wav
# Processed YAF_lot_neutral.wav
# Processed YAF_love_neutral.wav
# Processed YAF_luck_neutral.wav
# Processed YAF_make_neutral.wav
# Processed YAF_match_neutral.wav
# Processed YAF_merge_neutral.wav
# Processed YAF_mess_neutral.wav
# Processed YAF_met_neutral.wav
# Processed YAF_mill_neutral.wav
# Processed YAF_mob_neutral.wav
# Processed YAF_mode_neutral.wav
# Processed YAF_mood_neutral.wav
# Processed YAF_moon_neutral.wav
# Processed YAF_mop_neutral.wav
# Processed YAF_mouse_neutral.wav
# Processed YAF_nag_neutral.wav
# Processed YAF_name_neutral.wav
# Processed YAF_near_neutral.wav
# Processed YAF_neat_neutral.wav
# Processed YAF_nice_neutral.wav
# Processed YAF_note_neutral.wav
# Processed YAF_numb_neutral.wav
# Processed YAF_pad_neutral.wav
# Processed YAF_page_neutral.wav
# Processed YAF_pain_neutral.wav
# Processed YAF_pass_neutral.wav
# Processed YAF_pearl_neutral.wav
# Processed YAF_peg_neutral.wav
# Processed YAF_perch_neutral.wav
# Processed YAF_phone_neutral.wav
# Processed YAF_pick_neutral.wav
# Processed YAF_pike_neutral.wav
# Processed YAF_pole_neutral.wav
# Processed YAF_pool_neutral.wav
# Processed YAF_puff_neutral.wav
# Processed YAF_rag_neutral.wav
# Processed YAF_raid_neutral.wav
# Processed YAF_rain_neutral.wav
# Processed YAF_raise_neutral.wav
# Processed YAF_rat_neutral.wav
# Processed YAF_reach_neutral.wav
# Processed YAF_read_neutral.wav
# Processed YAF_red_neutral.wav
# Processed YAF_ring_neutral.wav
# Processed YAF_ripe_neutral.wav
# Processed YAF_road_neutral.wav
# Processed YAF_room_neutral.wav
# Processed YAF_rose_neutral.wav
# Processed YAF_rot_neutral.wav
# Processed YAF_rough_neutral.wav
# Processed YAF_rush_neutral.wav
# Processed YAF_said_neutral.wav
# Processed YAF_sail_neutral.wav
# Processed YAF_search_neutral.wav
# Processed YAF_seize_neutral.wav
# Processed YAF_sell_neutral.wav
# Processed YAF_shack_neutral.wav
# Processed YAF_shall_neutral.wav
# Processed YAF_shawl_neutral.wav
# Processed YAF_sheep_neutral.wav
# Processed YAF_shirt_neutral.wav
# Processed YAF_should_neutral.wav
# Processed YAF_shout_neutral.wav
# Processed YAF_size_neutral.wav
# Processed YAF_soap_neutral.wav
# Processed YAF_soup_neutral.wav
# Processed YAF_sour_neutral.wav
# Processed YAF_south_neutral.wav
# Processed YAF_sub_neutral.wav
# Processed YAF_such_neutral.wav
# Processed YAF_sure_neutral.wav
# Processed YAF_take_neutral.wav
# Processed YAF_talk_neutral.wav
# Processed YAF_tape_neutral.wav
# Processed YAF_team_neutral.wav
# Processed YAF_tell_neutral.wav
# Processed YAF_thin_neutral.wav
# Processed YAF_third_neutral.wav
# Processed YAF_thought_neutral.wav
# Processed YAF_thumb_neutral.wav
# Processed YAF_time_neutral.wav
# Processed YAF_tip_neutral.wav
# Processed YAF_tire_neutral.wav
# Processed YAF_ton_neutral.wav
# Processed YAF_tool_neutral.wav
# Processed YAF_tough_neutral.wav
# Processed YAF_turn_neutral.wav
# Processed YAF_vine_neutral.wav
# Processed YAF_voice_neutral.wav
# Processed YAF_void_neutral.wav
# Processed YAF_vote_neutral.wav
# Processed YAF_wag_neutral.wav
# Processed YAF_walk_neutral.wav
# Processed YAF_wash_neutral.wav
# Processed YAF_week_neutral.wav
# Processed YAF_wheat_neutral.wav
# Processed YAF_when_neutral.wav
# Processed YAF_which_neutral.wav
# Processed YAF_whip_neutral.wav
# Processed YAF_white_neutral.wav
# Processed YAF_wife_neutral.wav
# Processed YAF_wire_neutral.wav
# Processed YAF_witch_neutral.wav
# Processed YAF_yearn_neutral.wav
# Processed YAF_yes_neutral.wav
# Processed YAF_young_neutral.wav
# Processed YAF_youth_neutral.wav
# Processed YAF_back_ps.wav
# Processed YAF_bar_ps.wav
# Processed YAF_base_ps.wav
# Processed YAF_bath_ps.wav
# Processed YAF_bean_ps.wav
# Processed YAF_beg_ps.wav
# Processed YAF_bite_ps.wav
# Processed YAF_boat_ps.wav
# Processed YAF_bone_ps.wav
# Processed YAF_book_ps.wav
# Processed YAF_bought_ps.wav
# Processed YAF_burn_ps.wav
# Processed YAF_cab_ps.wav
# Processed YAF_calm_ps.wav
# Processed YAF_came_ps.wav
# Processed YAF_cause_ps.wav
# Processed YAF_chain_ps.wav
# Processed YAF_chair_ps.wav
# Processed YAF_chalk_ps.wav
# Processed YAF_chat_ps.wav
# Processed YAF_check_ps.wav
# Processed YAF_cheek_ps.wav
# Processed YAF_chief_ps.wav
# Processed YAF_choice_ps.wav
# Processed YAF_cool_ps.wav
# Processed YAF_dab_ps.wav
# Processed YAF_date_ps.wav
# Processed YAF_dead_ps.wav
# Processed YAF_death_ps.wav
# Processed YAF_deep_ps.wav
# Processed YAF_dime_ps.wav
# Processed YAF_dip_ps.wav
# Processed YAF_ditch_ps.wav
# Processed YAF_dodge_ps.wav
# Processed YAF_dog_ps.wav
# Processed YAF_doll_ps.wav
# Processed YAF_door_ps.wav
# Processed YAF_fail_ps.wav
# Processed YAF_fall_ps.wav
# Processed YAF_far_ps.wav
# Processed YAF_fat_ps.wav
# Processed YAF_fit_ps.wav
# Processed YAF_five_ps.wav
# Processed YAF_food_ps.wav
# Processed YAF_gap_ps.wav
# Processed YAF_gas_ps.wav
# Processed YAF_gaze_ps.wav
# Processed YAF_germ_ps.wav
# Processed YAF_get_ps.wav
# Processed YAF_gin_ps.wav
# Processed YAF_goal_ps.wav
# Processed YAF_good_ps.wav
# Processed YAF_goose_ps.wav
# Processed YAF_gun_ps.wav
# Processed YAF_half_ps.wav
# Processed YAF_hall_ps.wav
# Processed YAF_hash_ps.wav
# Processed YAF_hate_ps.wav
# Processed YAF_have_ps.wav
# Processed YAF_haze_ps.wav
# Processed YAF_hire_ps.wav
# Processed YAF_hit_ps.wav
# Processed YAF_hole_ps.wav
# Processed YAF_home_ps.wav
# Processed YAF_hurl_ps.wav
# Processed YAF_hush_ps.wav
# Processed YAF_jail_ps.wav
# Processed YAF_jar_ps.wav
# Processed YAF_join_ps.wav
# Processed YAF_judge_ps.wav
# Processed YAF_jug_ps.wav
# Processed YAF_juice_ps.wav
# Processed YAF_keen_ps.wav
# Processed YAF_keep_ps.wav
# Processed YAF_keg_ps.wav
# Processed YAF_kick_ps.wav
# Processed YAF_kill_ps.wav
# Processed YAF_king_ps.wav
# Processed YAF_kite_ps.wav
# Processed YAF_knock_ps.wav
# Processed YAF_late_ps.wav
# Processed YAF_laud_ps.wav
# Processed YAF_lean_ps.wav
# Processed YAF_learn_ps.wav
# Processed YAF_lease_ps.wav
# Processed YAF_lid_ps.wav
# Processed YAF_life_ps.wav
# Processed YAF_limb_ps.wav
# Processed YAF_live_ps.wav
# Processed YAF_loaf_ps.wav
# Processed YAF_long_ps.wav
# Processed YAF_lore_ps.wav
# Processed YAF_lose_ps.wav
# Processed YAF_lot_ps.wav
# Processed YAF_love_ps.wav
# Processed YAF_luck_ps.wav
# Processed YAF_make_ps.wav
# Processed YAF_match_ps.wav
# Processed YAF_merge_ps.wav
# Processed YAF_mess_ps.wav
# Processed YAF_met_ps.wav
# Processed YAF_mill_ps.wav
# Processed YAF_mob_ps.wav
# Processed YAF_mode_ps.wav
# Processed YAF_mood_ps.wav
# Processed YAF_moon_ps.wav
# Processed YAF_mop_ps.wav
# Processed YAF_mouse_ps.wav
# Processed YAF_nag_ps.wav
# Processed YAF_name_ps.wav
# Processed YAF_near_ps.wav
# Processed YAF_neat_ps.wav
# Processed YAF_nice_ps.wav
# Processed YAF_note_ps.wav
# Processed YAF_numb_ps.wav
# Processed YAF_pad_ps.wav
# Processed YAF_page_ps.wav
# Processed YAF_pain_ps.wav
# Processed YAF_pass_ps.wav
# Processed YAF_pearl_ps.wav
# Processed YAF_peg_ps.wav
# Processed YAF_perch_ps.wav
# Processed YAF_phone_ps.wav
# Processed YAF_pick_ps.wav
# Processed YAF_pike_ps.wav
# Processed YAF_pole_ps.wav
# Processed YAF_pool_ps.wav
# Processed YAF_puff_ps.wav
# Processed YAF_rag_ps.wav
# Processed YAF_raid_ps.wav
# Processed YAF_rain_ps.wav
# Processed YAF_raise_ps.wav
# Processed YAF_rat_ps.wav
# Processed YAF_reach_ps.wav
# Processed YAF_read_ps.wav
# Processed YAF_red_ps.wav
# Processed YAF_ring_ps.wav
# Processed YAF_ripe_ps.wav
# Processed YAF_road_ps.wav
# Processed YAF_room_ps.wav
# Processed YAF_rose_ps.wav
# Processed YAF_rot_ps.wav
# Processed YAF_rough_ps.wav
# Processed YAF_rush_ps.wav
# Processed YAF_said_ps.wav
# Processed YAF_sail_ps.wav
# Processed YAF_search_ps.wav
# Processed YAF_seize_ps.wav
# Processed YAF_sell_ps.wav
# Processed YAF_shack_ps.wav
# Processed YAF_shall_ps.wav
# Processed YAF_shawl_ps.wav
# Processed YAF_sheep_ps.wav
# Processed YAF_shirt_ps.wav
# Processed YAF_should_ps.wav
# Processed YAF_shout_ps.wav
# Processed YAF_size_ps.wav
# Processed YAF_soap_ps.wav
# Processed YAF_soup_ps.wav
# Processed YAF_sour_ps.wav
# Processed YAF_south_ps.wav
# Processed YAF_sub_ps.wav
# Processed YAF_such_ps.wav
# Processed YAF_sure_ps.wav
# Processed YAF_take_ps.wav
# Processed YAF_talk_ps.wav
# Processed YAF_tape_ps.wav
# Processed YAF_team_ps.wav
# Processed YAF_tell_ps.wav
# Processed YAF_thin_ps.wav
# Processed YAF_third_ps.wav
# Processed YAF_thought_ps.wav
# Processed YAF_thumb_ps.wav
# Processed YAF_time_ps.wav
# Processed YAF_tip_ps.wav
# Processed YAF_tire_ps.wav
# Processed YAF_ton_ps.wav
# Processed YAF_tool_ps.wav
# Processed YAF_tough_ps.wav
# Processed YAF_turn_ps.wav
# Processed YAF_vine_ps.wav
# Processed YAF_voice_ps.wav
# Processed YAF_void_ps.wav
# Processed YAF_vote_ps.wav
# Processed YAF_wag_ps.wav
# Processed YAF_walk_ps.wav
# Processed YAF_wash_ps.wav
# Processed YAF_week_ps.wav
# Processed YAF_wheat_ps.wav
# Processed YAF_when_ps.wav
# Processed YAF_which_ps.wav
# Processed YAF_whip_ps.wav
# Processed YAF_white_ps.wav
# Processed YAF_wife_ps.wav
# Processed YAF_wire_ps.wav
# Processed YAF_witch_ps.wav
# Processed YAF_yearn_ps.wav
# Processed YAF_yes_ps.wav
# Processed YAF_young_ps.wav
# Processed YAF_youth_ps.wav
# Processed YAF_back_sad.wav
# Processed YAF_bar_sad.wav
# Processed YAF_base_sad.wav
# Processed YAF_bath_sad.wav
# Processed YAF_bean_sad.wav
# Processed YAF_beg_sad.wav
# Processed YAF_bite_sad.wav
# Processed YAF_boat_sad.wav
# Processed YAF_bone_sad.wav
# Processed YAF_book_sad.wav
# Processed YAF_bought_sad.wav
# Processed YAF_burn_sad.wav
# Processed YAF_cab_sad.wav
# Processed YAF_calm_sad.wav
# Processed YAF_came_sad.wav
# Processed YAF_cause_sad.wav
# Processed YAF_chain_sad.wav
# Processed YAF_chair_sad.wav
# Processed YAF_chalk_sad.wav
# Processed YAF_chat_sad.wav
# Processed YAF_check_sad.wav
# Processed YAF_cheek_sad.wav
# Processed YAF_chief_sad.wav
# Processed YAF_choice_sad.wav
# Processed YAF_cool_sad.wav
# Processed YAF_dab_sad.wav
# Processed YAF_date_sad.wav
# Processed YAF_dead_sad.wav
# Processed YAF_death_sad.wav
# Processed YAF_deep_sad.wav
# Processed YAF_dime_sad.wav
# Processed YAF_dip_sad.wav
# Processed YAF_ditch_sad.wav
# Processed YAF_dodge_sad.wav
# Processed YAF_dog_sad.wav
# Processed YAF_doll_sad.wav
# Processed YAF_door_sad.wav
# Processed YAF_fail_sad.wav
# Processed YAF_fall_sad.wav
# Processed YAF_far_sad.wav
# Processed YAF_fat_sad.wav
# Processed YAF_fit_sad.wav
# Processed YAF_five_sad.wav
# Processed YAF_food_sad.wav
# Processed YAF_gap_sad.wav
# Processed YAF_gas_sad.wav
# Processed YAF_gaze_sad.wav
# Processed YAF_germ_sad.wav
# Processed YAF_get_sad.wav
# Processed YAF_gin_sad.wav
# Processed YAF_goal_sad.wav
# Processed YAF_good_sad.wav
# Processed YAF_goose_sad.wav
# Processed YAF_gun_sad.wav
# Processed YAF_half_sad.wav
# Processed YAF_hall_sad.wav
# Processed YAF_hash_sad.wav
# Processed YAF_hate_sad.wav
# Processed YAF_have_sad.wav
# Processed YAF_haze_sad.wav
# Processed YAF_hire_sad.wav
# Processed YAF_hit_sad.wav
# Processed YAF_hole_sad.wav
# Processed YAF_home_sad.wav
# Processed YAF_hurl_sad.wav
# Processed YAF_hush_sad.wav
# Processed YAF_jail_sad.wav
# Processed YAF_jar_sad.wav
# Processed YAF_join_sad.wav
# Processed YAF_judge_sad.wav
# Processed YAF_jug_sad.wav
# Processed YAF_juice_sad.wav
# Processed YAF_keen_sad.wav
# Processed YAF_keep_sad.wav
# Processed YAF_keg_sad.wav
# Processed YAF_kick_sad.wav
# Processed YAF_kill_sad.wav
# Processed YAF_king_sad.wav
# Processed YAF_kite_sad.wav
# Processed YAF_knock_sad.wav
# Processed YAF_late_sad.wav
# Processed YAF_laud_sad.wav
# Processed YAF_lean_sad.wav
# Processed YAF_learn_sad.wav
# Processed YAF_lease_sad.wav
# Processed YAF_lid_sad.wav
# Processed YAF_life_sad.wav
# Processed YAF_limb_sad.wav
# Processed YAF_live_sad.wav
# Processed YAF_loaf_sad.wav
# Processed YAF_long_sad.wav
# Processed YAF_lore_sad.wav
# Processed YAF_lose_sad.wav
# Processed YAF_lot_sad.wav
# Processed YAF_love_sad.wav
# Processed YAF_luck_sad.wav
# Processed YAF_make_sad.wav
# Processed YAF_match_sad.wav
# Processed YAF_merge_sad.wav
# Processed YAF_mess_sad.wav
# Processed YAF_met_sad.wav
# Processed YAF_mill_sad.wav
# Processed YAF_mob_sad.wav
# Processed YAF_mode_sad.wav
# Processed YAF_mood_sad.wav
# Processed YAF_moon_sad.wav
# Processed YAF_mop_sad.wav
# Processed YAF_mouse_sad.wav
# Processed YAF_nag_sad.wav
# Processed YAF_name_sad.wav
# Processed YAF_near_sad.wav
# Processed YAF_neat_sad.wav
# Processed YAF_nice_sad.wav
# Processed YAF_note_sad.wav
# Processed YAF_numb_sad.wav
# Processed YAF_pad_sad.wav
# Processed YAF_page_sad.wav
# Processed YAF_pain_sad.wav
# Processed YAF_pass_sad.wav
# Processed YAF_pearl_sad.wav
# Processed YAF_peg_sad.wav
# Processed YAF_perch_sad.wav
# Processed YAF_phone_sad.wav
# Processed YAF_pick_sad.wav
# Processed YAF_pike_sad.wav
# Processed YAF_pole_sad.wav
# Processed YAF_pool_sad.wav
# Processed YAF_puff_sad.wav
# Processed YAF_rag_sad.wav
# Processed YAF_raid_sad.wav
# Processed YAF_rain_sad.wav
# Processed YAF_raise_sad.wav
# Processed YAF_rat_sad.wav
# Processed YAF_reach_sad.wav
# Processed YAF_read_sad.wav
# Processed YAF_red_sad.wav
# Processed YAF_ring_sad.wav
# Processed YAF_ripe_sad.wav
# Processed YAF_road_sad.wav
# Processed YAF_room_sad.wav
# Processed YAF_rose_sad.wav
# Processed YAF_rot_sad.wav
# Processed YAF_rough_sad.wav
# Processed YAF_rush_sad.wav
# Processed YAF_said_sad.wav
# Processed YAF_sail_sad.wav
# Processed YAF_search_sad.wav
# Processed YAF_seize_sad.wav
# Processed YAF_sell_sad.wav
# Processed YAF_shack_sad.wav
# Processed YAF_shall_sad.wav
# Processed YAF_shawl_sad.wav
# Processed YAF_sheep_sad.wav
# Processed YAF_shirt_sad.wav
# Processed YAF_should_sad.wav
# Processed YAF_shout_sad.wav
# Processed YAF_size_sad.wav
# Processed YAF_soap_sad.wav
# Processed YAF_soup_sad.wav
# Processed YAF_sour_sad.wav
# Processed YAF_south_sad.wav
# Processed YAF_sub_sad.wav
# Processed YAF_such_sad.wav
# Processed YAF_sure_sad.wav
# Processed YAF_take_sad.wav
# Processed YAF_talk_sad.wav
# Processed YAF_tape_sad.wav
# Processed YAF_team_sad.wav
# Processed YAF_tell_sad.wav
# Processed YAF_thin_sad.wav
# Processed YAF_third_sad.wav
# Processed YAF_thought_sad.wav
# Processed YAF_thumb_sad.wav
# Processed YAF_time_sad.wav
# Processed YAF_tip_sad.wav
# Processed YAF_tire_sad.wav
# Processed YAF_ton_sad.wav
# Processed YAF_tool_sad.wav
# Processed YAF_tough_sad.wav
# Processed YAF_turn_sad.wav
# Processed YAF_vine_sad.wav
# Processed YAF_voice_sad.wav
# Processed YAF_void_sad.wav
# Processed YAF_vote_sad.wav
# Processed YAF_wag_sad.wav
# Processed YAF_walk_sad.wav
# Processed YAF_wash_sad.wav
# Processed YAF_week_sad.wav
# Processed YAF_wheat_sad.wav
# Processed YAF_when_sad.wav
# Processed YAF_which_sad.wav
# Processed YAF_whip_sad.wav
# Processed YAF_white_sad.wav
# Processed YAF_wife_sad.wav
# Processed YAF_wire_sad.wav
# Processed YAF_witch_sad.wav
# Processed YAF_yearn_sad.wav
# Processed YAF_yes_sad.wav
# Processed YAF_young_sad.wav
# Processed YAF_youth_sad.wav
#              filename age category emotion  mfcc_mean    mfcc_max    mfcc_min  \
# 0  OAF_back_angry.wav          old   angry  -6.170317  145.766510 -589.788757
# 1   OAF_bar_angry.wav          old   angry  -6.393609  158.041290 -692.956116
# 2  OAF_base_angry.wav          old   angry  -6.367840  143.906708 -639.682129
# 3  OAF_bath_angry.wav          old   angry  -5.855876  143.848190 -617.731323
# 4  OAF_bean_angry.wav          old   angry  -6.129452  151.921631 -638.428101
#
#    mfcc_median   mfcc_std  mfcc_skew  mfcc_kurtosis  ...   rms_std  rms_skew  \
# 0     2.805268  66.587997   0.083930      -0.510136  ...  0.035433  0.749333
# 1     3.103088  76.623047   0.100141      -0.148079  ...  0.016400  0.114452
# 2     2.140062  70.524620   0.017008      -0.406255  ...  0.027158  0.830990
# 3     2.167984  66.934021   0.041791      -0.476297  ...  0.036992  0.673219
# 4     1.892702  70.998703   0.036565      -0.359555  ...  0.019765  0.670254
#
#    rms_kurtosis  zero_cr_mean  zero_cr_max  zero_cr_min  zero_cr_median  \
# 0      0.269231      0.058228     0.109863     0.014648        0.056885
# 1     -1.015164      0.086060     0.393555     0.003418        0.074707
# 2      0.218074      0.076689     0.269043     0.018555        0.065430
# 3     -0.399607      0.065247     0.233398     0.017090        0.052246
# 4     -0.011022      0.060059     0.226074     0.003418        0.051270
#
#    zero_cr_std  zero_cr_skew  zero_cr_kurtosis
# 0     0.026083      0.258180         -0.571654
# 1     0.071912      2.279870          6.089196
# 2     0.055090      1.914980          3.807466
# 3     0.045627      2.059895          4.608866
# 4     0.046195      1.887817          4.059623
#
# [5 rows x 72 columns]

# %%
df.shape
# Out:
# (1440, 77)

# %%
df_c.shape
# Out:
# (7442, 73)

# %%
df_t.shape
# Out:
# (2800, 72)

# %%
df.iloc[140: 150, 30: 35]
# Out:
#      chroma_min  chroma_median  chroma_std  chroma_skew  chroma_kurtosis
# 140    0.003505       0.238598    0.305701     0.942927        -0.000231
# 141    0.000604       0.360917    0.335929     0.367791        -1.151137
# 142    0.000592       0.280720    0.331230     0.634349        -0.779109
# 143    0.000831       0.308117    0.340419     0.505528        -1.081219
# 144    0.000132       0.228411    0.327293     0.781575        -0.685811
# 145    0.000407       0.222325    0.334393     0.764258        -0.680855
# 146    0.001111       0.373075    0.351353     0.300714        -1.316280
# 147    0.001709       0.169051    0.326575     1.070677         0.196587
# 148    0.003244       0.349546    0.302007     0.616560        -0.393293
# 149    0.002905       0.263593    0.304389     0.871895        -0.217494

# %%
df_c.iloc[140: 150, 25: 30]
# Out:
#      chroma_mean  chroma_min  chroma_median  chroma_std  chroma_skew
# 140     0.290673    0.000534       0.186333    0.306675     1.001829
# 141     0.326867    0.000499       0.226461    0.306865     0.962353
# 142     0.362377    0.000536       0.267775    0.318924     0.748764
# 143     0.323289    0.003758       0.200225    0.312992     1.114899
# 144     0.399191    0.001927       0.331602    0.304867     0.621731
# 145     0.406545    0.009924       0.339020    0.301116     0.650642
# 146     0.317708    0.001313       0.195188    0.311257     1.103876
# 147     0.421541    0.015448       0.358921    0.291140     0.609152
# 148     0.354266    0.002383       0.252441    0.310167     0.853069
# 149     0.302760    0.001948       0.184652    0.312111     1.181405

# %%
df_t.iloc[140: 150, 25: 30]
# Out:
#      chroma_min  chroma_median  chroma_std  chroma_skew  chroma_kurtosis
# 140    0.000072       0.022207    0.305801     2.149386         4.453587
# 141    0.000231       0.051364    0.313491     1.606757         1.874470
# 142    0.000126       0.049983    0.326259     1.606279         2.209270
# 143    0.000104       0.035838    0.307153     2.009354         4.406334
# 144    0.000120       0.095962    0.330274     1.113760         0.420411
# 145    0.000089       0.061317    0.330738     1.369994         0.962655
# 146    0.000048       0.080500    0.345413     1.074116         0.145642
# 147    0.000099       0.030666    0.332094     1.454260         1.275023
# 148    0.000110       0.086232    0.327455     1.338970         1.406165
# 149    0.000211       0.093724    0.323825     1.269850         0.513373

# %%
# df.shape  # shape with 4 parts after dropping silent segments (3276, 53)

# %%
# Function used is above, saving for archive
# def split_and_process(file_path):
#     y, sr = librosa.load(file_path, sr=None)
#     segment_length = len(y) // 3  # Adjust number of segments as needed, current is 3

#     segments_data = []
#     for i in range(3):  # Adjust number of segments as needed, current is 3
#         start = i * segment_length
#         end = None if i == 2 else (i + 1) * segment_length  # Adjust number of segments as needed, current is 3
#         segment = y[start:end]

#         modified_filename = f"{os.path.basename(file_path).rstrip('.wav')}_part_{chr(97 + i)}.wav"

#         if is_silent(segment, threshold=0.001):
#             silent_data.append({'filename': modified_filename, 'is_silent': True})
#             continue  # Skip processing this segment

#         features = extract_features(segment, sr, modified_filename)
#         segments_data.append(features)

#     return segments_data

# %%
# Function used is above, saving for archive
# def split_and_process(file_path):
#     y, sr = librosa.load(file_path, sr=None)
#     segment_length = len(y) // 4  # Adjust number of segments as needed, current is 4

#     segments_data = []
#     for i in range(4):  # Adjust number of segments as needed, current is 4
#         start = i * segment_length
#         end = None if i == 3 else (i + 1) * segment_length  # Adjust number of segments as needed, current is 4
#         segment = y[start:end]

#         modified_filename = f"{os.path.basename(file_path).rstrip('.wav')}_part_{chr(97 + i)}.wav"

#         if is_silent(segment, threshold=0.001):
#             silent_data.append({'filename': modified_filename, 'is_silent': True})
#             continue  # Skip processing this segment

#         features = extract_features(segment, sr, modified_filename)
#         segments_data.append(features)

#     return segments_data

# %% [markdown]
# ## Exploring the dataframe<a id='Exploring_the_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# ### Strong vs normal emotion<a id='Strong_vs_normal_emotion'></a>

# %%
# Replace 1 and 2 with 'Normal' and 'Strong' in the 'voice_intensity' column
# df['voice_intensity'] = df['voice_intensity'].replace({1: 'Normal', 2: 'Strong'})

# Create a count plot
sns.countplot(x='voice_intensity', data=df)

# Adding labels and title for clarity
plt.xlabel('Voice Intensity')
plt.ylabel('Count')
plt.title('Distribution of Voice Intensity Types')
plt.xticks([0, 1], ['Normal', 'Strong'])

# Display the plot
plt.show()

# %% [markdown]
# ### Number of repeated phrases<a id='Number_of_repeated_phrases'></a>

# %%
# Replace 1 and 2 with 'First' and 'Second' in the 'statement_repetition' column
# df['statement_repetition'] = df['statement_repetition'].replace({1: 'First', 2: 'Second'})

# Create a count plot
sns.countplot(x='statement_repetition', data=df)

# Adding labels and title for clarity
plt.xlabel('Statement Repetition')
plt.ylabel('Count')
plt.title('Distribution of Statement Repetition Types')
plt.xticks([0, 1], ['First', 'Second'])

# Display the plot
plt.show()

# %% [markdown]
# ### Number of Male vs Female actors<a id='Number_of_Male_vs_Female_actors'></a>

# %%
# Replace 1 and 2 with 'Male' and 'Female' in the 'actor_gender' column
# df['actor_gender'] = df['actor_gender'].replace({1: 'Male', 2: 'Female'})

# Create a count plot
sns.countplot(x='actor_gender', data=df)

# Adding labels and title for clarity
plt.xlabel('Actor Gender')
plt.ylabel('Count')
plt.title('Distribution of Actor Gender Types')
plt.xticks([0, 1], ['Male', 'Female'])

# Display the plot
plt.show()

# %% [markdown]
# ### Emotions

# %%
# Create a count plot
sns.countplot(x='emotion', data=df)

# Adding labels and title for clarity
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.title('Distribution of Emotion Types')
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7], ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised'])

# Display the plot
plt.show()

# %%
neutral = df[df['emotion'] == 1].sum
print(neutral)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                       filename  modality  vocal_channel  emotion  \
# 0     03-01-01-01-01-01-01.wav         3              1        1
# 1     03-01-01-01-01-02-01.wav         3              1        1
# 2     03-01-01-01-02-01-01.wav         3              1        1
# 3     03-01-01-01-02-02-01.wav         3              1        1
# 60    03-01-01-01-01-01-02.wav         3              1        1
# ...                        ...       ...            ...      ...
# 1323  03-01-01-01-02-02-23.wav         3              1        1
# 1380  03-01-01-01-01-01-24.wav         3              1        1
# 1381  03-01-01-01-01-02-24.wav         3              1        1
# 1382  03-01-01-01-02-01-24.wav         3              1        1
# 1383  03-01-01-01-02-02-24.wav         3              1        1
#
#       voice_intensity  statement  statement_repetition  actor_gender  \
# 0                   1          1                     1             1
# 1                   1          1                     2             1
# 2                   1          2                     1             1
# 3                   1          2                     2             1
# 60                  1          1                     1             2
# ...               ...        ...                   ...           ...
# 1323                1          2                     2             1
# 1380                1          1                     1             2
# 1381                1          1                     2             2
# 1382                1          2                     1             2
# 1383                1          2                     2             2
#
#       mfcc_mean    mfcc_max  ...   rms_std  rms_skew  rms_kurtosis  \
# 0    -13.750966  208.771698  ...  0.002752  0.523488     -0.223807
# 1    -14.013200  203.445557  ...  0.003002  0.472005     -0.447499
# 2    -13.286643  212.631989  ...  0.003825  1.126351      0.754771
# 3    -13.380160  214.319244  ...  0.004013  1.583204      1.841371
# 60   -12.129038  204.145828  ...  0.005278  0.768007     -0.301311
# ...         ...         ...  ...       ...       ...           ...
# 1323 -14.056429  227.692963  ...  0.007528  0.402854     -0.280709
# 1380 -15.871293  179.395660  ...  0.003105  0.665161     -0.333634
# 1381 -16.059326  188.613190  ...  0.002967  0.492121     -0.998485
# 1382 -14.766688  209.600159  ...  0.003327  1.736546      3.310030
# 1383 -15.450417  168.492401  ...  0.004612  1.116098      1.001256
#
#       zero_cr_mean  zero_cr_max  zero_cr_min  zero_cr_median  zero_cr_std  \
# 0         0.071506     0.208984     0.023438        0.046875     0.049214
# 1         0.063912     0.183105     0.019531        0.048340     0.042300
# 2         0.086652     0.424316     0.014648        0.048340     0.091483
# 3         0.088229     0.406250     0.013184        0.047852     0.093873
# 60        0.095346     0.290039     0.020020        0.082520     0.059171
# ...            ...          ...          ...             ...          ...
# 1323      0.096098     0.491699     0.015137        0.064697     0.097698
# 1380      0.096849     0.393066     0.025879        0.074707     0.075437
# 1381      0.107849     0.375488     0.031738        0.079834     0.083825
# 1382      0.096301     0.534668     0.024902        0.060059     0.109460
# 1383      0.117877     0.529297     0.026855        0.070801     0.120440
#
#       zero_cr_skew  zero_cr_kurtosis
# 0         1.349598          0.792986
# 1         1.347601          0.843776
# 2         2.158822          4.017514
# 3         1.803562          2.245144
# 60        1.552441          2.514878
# ...            ...               ...
# 1323      2.527505          6.289644
# 1380      2.177094          5.019164
# 1381      1.746450          2.218911
# 1382      2.842609          7.208756
# 1383      2.055092          3.192534
#
# [96 rows x 77 columns]>

# %% [markdown]
# ### Statements

# %%
# Create a count plot
sns.countplot(x='statement', data=df)

# Adding labels and title for clarity
plt.xlabel('Statement spoken')
plt.ylabel('Count')
plt.title('Distribution of statement Types')
plt.xticks([0, 1], ["Kids are talking by the door", "Dogs are sitting by the door"])

# Display the plot
plt.show()

# %% [markdown]
# ## Cleaning the dataframe<a id='Cleaning_the_dataframe'></a>

# %% [markdown]
# *[Contents](#Contents)

# %% [markdown]
# ### Checking for duplicate values RAVDESS<a id='Checking_for_duplicate_values_RAVDESS'></a>

# %%
# Checking for unique row data
duplicate_rows = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows:  0

# %%
df.columns
# Out:
# Index(['filename', 'modality', 'vocal_channel', 'emotion', 'voice_intensity',
#        'statement', 'statement_repetition', 'actor_gender', 'mfcc_mean',
#        'mfcc_max', 'mfcc_min', 'mfcc_median', 'mfcc_std', 'mfcc_skew',
#        'mfcc_kurtosis', 'mfcc_delta_mean', 'mfcc_delta_max', 'mfcc_delta_min',
#        'mfcc_delta_median', 'mfcc_delta_std', 'mfcc_delta_skew',
#        'mfcc_delta_kurtosis', 'mfcc_delta2_mean', 'mfcc_delta2_max',
#        'mfcc_delta2_min', 'mfcc_delta2_median', 'mfcc_delta2_std',
#        'mfcc_delta2_skew', 'mfcc_delta2_kurtosis', 'chroma_mean', 'chroma_min',
#        'chroma_median', 'chroma_std', 'chroma_skew', 'chroma_kurtosis',
#        'mel_mean', 'mel_max', 'mel_min', 'mel_median', 'mel_std', 'mel_skew',
#        'mel_kurtosis', 'contrast_mean', 'contrast_max', 'contrast_min',
#        'contrast_median', 'contrast_std', 'contrast_skew', 'contrast_kurtosis',
#        'centroid_mean', 'centroid_max', 'centroid_min', 'centroid_median',
#        'centroid_std', 'centroid_skew', 'centroid_kurtosis', 'roll_off_mean',
#        'roll_off_max', 'roll_off_min', 'roll_off_median', 'roll_off_std',
#        'roll_off_skew', 'roll_off_kurtosis', 'rms_mean', 'rms_max', 'rms_min',
#        'rms_median', 'rms_std', 'rms_skew', 'rms_kurtosis', 'zero_cr_mean',
#        'zero_cr_max', 'zero_cr_min', 'zero_cr_median', 'zero_cr_std',
#        'zero_cr_skew', 'zero_cr_kurtosis'],
#       dtype='object')

# %%
# Checking for duplicate column data / files
key_columns = ['filename']
duplicate_rows = df[df.duplicated(subset=key_columns)]
print("Number of duplicate rows based on key columns: ", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows based on key columns:  0

# %% [markdown]
# ### Cleaning up outliers

# %%
df['mfcc_mean'].describe()

sns.boxplot(x = df['mfcc_mean'])
# Out:
# <Axes: xlabel='mfcc_mean'>

# %%
df.shape
# Out:
# (1440, 77)

# %%
# # Creating a copy of the original dataframe to preserve it    # not filtering data anymore, limits data set too much
# df_f = df.copy()

# # Iterating over columns starting from the 7th column (index 6)
# for column in df_f.columns[8:]:
#     Q1 = df_f[column].quantile(0.25)
#     Q3 = df_f[column].quantile(0.75)
#     IQR = Q3 - Q1
#     filter = (df_f[column] >= Q1 - 8 * IQR) & (df_f[column] <= Q3 + 8 * IQR)
#     df_f = df_f[filter]

# # 'filtered_df' now has outliers removed from the last 47 columns
# # 'df' remains unchanged for comparison

# %%
# # Due to the loss of data size, both sets are preserved and performance will be run in tandem
# df_f.shape

# %% [markdown]
# ### Checking for missing values in RAVDESS<a id='Checking_for_missing_values_in_RAVDESS'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Getting a total of missing values
miss_val = df.isnull().sum().sum()
# filtered_miss_val = df_f.isnull().sum()

# Printing missing values
print(f"Total number of missing values: {miss_val}")
# Out:
# Total number of missing values: 25

# %%
# Select only numeric columns for the isinf check
numeric_df = df.select_dtypes(include=[np.number])

# Count the total number of infinite values (both positive and negative) in the numeric columns
infinite_values_count = np.isinf(numeric_df).values.sum()

# Print the count
print(f"Total number of infinite values in numeric columns: {infinite_values_count}")
# Out:
# Total number of infinite values in numeric columns: 20

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    missing_values = df.isna().any()
    print(missing_values)
# Out:
# filename                False
# modality                False
# vocal_channel           False
# emotion                 False
# voice_intensity         False
# statement               False
# statement_repetition    False
# actor_gender            False
# mfcc_mean               False
# mfcc_max                False
# mfcc_min                False
# mfcc_median             False
# mfcc_std                False
# mfcc_skew               False
# mfcc_kurtosis           False
# mfcc_delta_mean         False
# mfcc_delta_max          False
# mfcc_delta_min          False
# mfcc_delta_median       False
# mfcc_delta_std          False
# mfcc_delta_skew         False
# mfcc_delta_kurtosis     False
# mfcc_delta2_mean        False
# mfcc_delta2_max         False
# mfcc_delta2_min         False
# mfcc_delta2_median      False
# mfcc_delta2_std         False
# mfcc_delta2_skew        False
# mfcc_delta2_kurtosis    False
# chroma_mean             False
# chroma_min              False
# chroma_median           False
# chroma_std              False
# chroma_skew             False
# chroma_kurtosis         False
# mel_mean                False
# mel_max                 False
# mel_min                 False
# mel_median              False
# mel_std                 False
# mel_skew                False
# mel_kurtosis             True
# contrast_mean           False
# contrast_max            False
# contrast_min            False
# contrast_median         False
# contrast_std            False
# contrast_skew           False
# contrast_kurtosis       False
# centroid_mean           False
# centroid_max            False
# centroid_min            False
# centroid_median         False
# centroid_std            False
# centroid_skew           False
# centroid_kurtosis       False
# roll_off_mean           False
# roll_off_max            False
# roll_off_min            False
# roll_off_median         False
# roll_off_std            False
# roll_off_skew           False
# roll_off_kurtosis       False
# rms_mean                False
# rms_max                 False
# rms_min                 False
# rms_median              False
# rms_std                 False
# rms_skew                False
# rms_kurtosis            False
# zero_cr_mean            False
# zero_cr_max             False
# zero_cr_min             False
# zero_cr_median          False
# zero_cr_std             False
# zero_cr_skew            False
# zero_cr_kurtosis        False
# dtype: bool

# %%
# Check for infinite values and replace them with NaN, which can then be imputed or removed
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Filling in missing values with the mean
df['mel_kurtosis'].fillna(df['mel_kurtosis'].mean(), inplace=True)

# %% [markdown]
# ### Checking for missing values in CREMA-D<a id='Checking_for_missing_values_in_CREMA-D'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Getting a total of missing values
miss_val = df_c.isnull().sum().sum()
# filtered_miss_val = df_f.isnull().sum()

# Printing missing values
print(f"Total number of missing values: {miss_val}")
# Out:
# Total number of missing values: 51

# %%
# Select only numeric columns for the isinf check
numeric_df_c = df_c.select_dtypes(include=[np.number])

# Count the total number of infinite values (both positive and negative) in the numeric columns
infinite_values_count_c = np.isinf(numeric_df_c).values.sum()

# Print the count
print(f"Total number of infinite values in numeric columns: {infinite_values_count_c}")
# Out:
# Total number of infinite values in numeric columns: 17

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    missing_values = df_c.isna().any()
    print(missing_values)
# Out:
# filename                False
# statement               False
# emotion                 False
# voice_intensity         False
# mfcc_mean               False
# mfcc_max                False
# mfcc_min                False
# mfcc_median             False
# mfcc_std                False
# mfcc_skew                True
# mfcc_kurtosis            True
# mfcc_delta_mean         False
# mfcc_delta_max          False
# mfcc_delta_min          False
# mfcc_delta_median       False
# mfcc_delta_std          False
# mfcc_delta_skew         False
# mfcc_delta_kurtosis     False
# mfcc_delta2_mean        False
# mfcc_delta2_max         False
# mfcc_delta2_min         False
# mfcc_delta2_median      False
# mfcc_delta2_std         False
# mfcc_delta2_skew        False
# mfcc_delta2_kurtosis    False
# chroma_mean             False
# chroma_min              False
# chroma_median           False
# chroma_std              False
# chroma_skew              True
# chroma_kurtosis          True
# mel_mean                False
# mel_max                 False
# mel_min                 False
# mel_median              False
# mel_std                 False
# mel_skew                 True
# mel_kurtosis             True
# contrast_mean           False
# contrast_max            False
# contrast_min            False
# contrast_median         False
# contrast_std            False
# contrast_skew            True
# contrast_kurtosis        True
# centroid_mean           False
# centroid_max            False
# centroid_min            False
# centroid_median         False
# centroid_std            False
# centroid_skew            True
# centroid_kurtosis        True
# roll_off_mean           False
# roll_off_max            False
# roll_off_min            False
# roll_off_median         False
# roll_off_std            False
# roll_off_skew            True
# roll_off_kurtosis        True
# rms_mean                False
# rms_max                 False
# rms_min                 False
# rms_median              False
# rms_std                 False
# rms_skew                 True
# rms_kurtosis             True
# zero_cr_mean            False
# zero_cr_max             False
# zero_cr_min             False
# zero_cr_median          False
# zero_cr_std             False
# zero_cr_skew             True
# zero_cr_kurtosis         True
# dtype: bool

# %%
# Check for infinite values and replace them with NaN, which can then be imputed or removed
df_c.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Filling in missing values with the mean
df_c['mfcc_skew'].fillna(df_c['mfcc_skew'].mean(), inplace=True)
df_c['mfcc_kurtosis'].fillna(df_c['mfcc_kurtosis'].mean(), inplace=True)
df_c['chroma_skew'].fillna(df_c['chroma_skew'].mean(), inplace=True)
df_c['chroma_kurtosis'].fillna(df_c['chroma_kurtosis'].mean(), inplace=True)
df_c['mel_skew'].fillna(df_c['mel_skew'].mean(), inplace=True)
df_c['mel_kurtosis'].fillna(df_c['mel_kurtosis'].mean(), inplace=True)
df_c['contrast_skew'].fillna(df_c['contrast_skew'].mean(), inplace=True)
df_c['contrast_kurtosis'].fillna(df_c['contrast_kurtosis'].mean(), inplace=True)
df_c['centroid_skew'].fillna(df_c['centroid_skew'].mean(), inplace=True)
df_c['centroid_kurtosis'].fillna(df_c['centroid_kurtosis'].mean(), inplace=True)
df_c['roll_off_skew'].fillna(df_c['roll_off_skew'].mean(), inplace=True)
df_c['roll_off_kurtosis'].fillna(df_c['roll_off_kurtosis'].mean(), inplace=True)
df_c['rms_skew'].fillna(df_c['rms_skew'].mean(), inplace=True)
df_c['rms_kurtosis'].fillna(df_c['rms_kurtosis'].mean(), inplace=True)
df_c['zero_cr_skew'].fillna(df_c['zero_cr_skew'].mean(), inplace=True)
df_c['zero_cr_kurtosis'].fillna(df_c['zero_cr_kurtosis'].mean(), inplace=True)

# %% [markdown]
# ### Checking for missing values in TESS<a id='Checking_for_missing_values_in_TESS'></a>

# %%
# Getting a total of missing values
miss_val_t = df_t.isnull().sum().sum()
# filtered_miss_val = df_f.isnull().sum()

# Printing missing values
print(f"Total number of missing values: {miss_val_t}")
# Out:
# Total number of missing values: 0

# %%
# Select only numeric columns for the isinf check
numeric_df_t = df_t.select_dtypes(include=[np.number])

# Count the total number of infinite values (both positive and negative) in the numeric columns
infinite_values_count_t = np.isinf(numeric_df_t).values.sum()

# Print the count
print(f"Total number of infinite values in numeric columns: {infinite_values_count_t}")
# Out:
# Total number of infinite values in numeric columns: 0

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    missing_values = df_t.isna().any()
    print(missing_values)
# Out:
# filename                False
# age category            False
# emotion                 False
# mfcc_mean               False
# mfcc_max                False
# mfcc_min                False
# mfcc_median             False
# mfcc_std                False
# mfcc_skew               False
# mfcc_kurtosis           False
# mfcc_delta_mean         False
# mfcc_delta_max          False
# mfcc_delta_min          False
# mfcc_delta_median       False
# mfcc_delta_std          False
# mfcc_delta_skew         False
# mfcc_delta_kurtosis     False
# mfcc_delta2_mean        False
# mfcc_delta2_max         False
# mfcc_delta2_min         False
# mfcc_delta2_median      False
# mfcc_delta2_std         False
# mfcc_delta2_skew        False
# mfcc_delta2_kurtosis    False
# chroma_mean             False
# chroma_min              False
# chroma_median           False
# chroma_std              False
# chroma_skew             False
# chroma_kurtosis         False
# mel_mean                False
# mel_max                 False
# mel_min                 False
# mel_median              False
# mel_std                 False
# mel_skew                False
# mel_kurtosis            False
# contrast_mean           False
# contrast_max            False
# contrast_min            False
# contrast_median         False
# contrast_std            False
# contrast_skew           False
# contrast_kurtosis       False
# centroid_mean           False
# centroid_max            False
# centroid_min            False
# centroid_median         False
# centroid_std            False
# centroid_skew           False
# centroid_kurtosis       False
# roll_off_mean           False
# roll_off_max            False
# roll_off_min            False
# roll_off_median         False
# roll_off_std            False
# roll_off_skew           False
# roll_off_kurtosis       False
# rms_mean                False
# rms_max                 False
# rms_min                 False
# rms_median              False
# rms_std                 False
# rms_skew                False
# rms_kurtosis            False
# zero_cr_mean            False
# zero_cr_max             False
# zero_cr_min             False
# zero_cr_median          False
# zero_cr_std             False
# zero_cr_skew            False
# zero_cr_kurtosis        False
# dtype: bool

# %%
# Check for infinite values and replace them with NaN, which can then be imputed or removed
df_t.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# ### Distributions Of Feature Values<a id='Distributions_Of_Feature_Values'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
df.hist(figsize=(20,15))
plt.subplots_adjust(hspace=0.75, wspace=0.75);

# %% [markdown]
# ### Numeric data summary<a id='Numeric_data_summary'></a>

# %%
df.describe().transpose()
# Out:
#                    count      mean       std       min       25%       50%  \
# modality          1440.0  3.000000  0.000000  3.000000  3.000000  3.000000
# vocal_channel     1440.0  1.000000  0.000000  1.000000  1.000000  1.000000
# emotion           1440.0  4.733333  2.175356  1.000000  3.000000  5.000000
# voice_intensity   1440.0  1.466667  0.499061  1.000000  1.000000  1.000000
# statement         1440.0  1.500000  0.500174  1.000000  1.000000  1.500000
# ...                  ...       ...       ...       ...       ...       ...
# zero_cr_min       1440.0  0.022272  0.010230  0.000000  0.016602  0.021484
# zero_cr_median    1440.0  0.072537  0.022393  0.026855  0.056335  0.068848
# zero_cr_std       1440.0  0.093550  0.037291  0.021017  0.061742  0.092308
# zero_cr_skew      1440.0  1.734184  0.536485 -0.271995  1.349401  1.763532
# zero_cr_kurtosis  1440.0  2.601528  1.972416 -1.511448  1.111075  2.413227
#
#                        75%       max
# modality          3.000000  3.000000
# vocal_channel     1.000000  1.000000
# emotion           7.000000  8.000000
# voice_intensity   2.000000  2.000000
# statement         2.000000  2.000000
# ...                    ...       ...
# zero_cr_min       0.027344  0.080566
# zero_cr_median    0.084717  0.172363
# zero_cr_std       0.120443  0.242135
# zero_cr_skew      2.110491  3.024978
# zero_cr_kurtosis  3.953247  8.817852
#
# [76 rows x 8 columns]

# %% [markdown]
# ## Exporting DataFrame<a id='Exporting_DataFrame'></a>

# %% [markdown]
# *[Contents](#Contents)

# %%
# Exporting to CSV files
df.to_csv('voice_data_dw.csv', index=False)
df_c.to_csv('voice_data_dw_c.csv', index=False)
df_t.to_csv('voice_data_dw_t.csv', index=False)

# %% [markdown]
# ## Summary

# %% [markdown]
# The tests were successful and I was able to successfully import the files into a dataframe.  With a little examination
# of the features I was able to extract we can see an even number of male versus female actors. Same goes fort the repetition
# of statements but the intensity was sqewed but that is understandable since the 'neutral' emotion does not have a 'strong'
# intensity so there are less of them. I decided not to downsample the audio files upon further research. 16000 Hz seems to be
# the minimum standard for voice data and I'd prefer not to compromise the later model's ability to accurately predict
# emotions because of a reduction in quality. Next step is Exploratory Data Analysis and I'm excited to see what patterns arise.
